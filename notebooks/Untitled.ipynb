# %%
import pandas as pd

# %%
players = pd.read_csv("../input/FIFA19 - Ultimate Team players.csv")
# Out:
# C:\Users\Jan\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
players.head()
# Out:
#    player_ID player_name          player_extended_name      quality revision  \
# 0          1        Pelé      Arantes Nascimento Edson  Gold - Rare     Icon
# 1          2    Maradona                Diego Maradona  Gold - Rare     Icon
# 2          3     Ronaldo  Nazário de Lima Ronaldo Luís  Gold - Rare     Icon
# 3          4        Pelé      Arantes Nascimento Edson  Gold - Rare     Icon
# 4          5    Maradona                Diego Maradona  Gold - Rare     Icon
#
#   origin  overall   club league nationality  \
# 0    NaN       98  Icons  Icons      Brazil
# 1    NaN       97  Icons  Icons   Argentina
# 2    NaN       96  Icons  Icons      Brazil
# 3    NaN       95  Icons  Icons      Brazil
# 4    NaN       95  Icons  Icons   Argentina
#
#                          ...                            rf  lf  rw  lw  st  \
# 0                        ...                          96.0  96  96  96  95
# 1                        ...                          94.0  94  94  94  90
# ...

# %%
players[players["nationality"] == "Spain"]["club"]
# Out:
# 15                          Icons
# 20                          Icons
# 34                          Icons
# 75                          Icons
# 126                         Icons
# 203             Borussia Dortmund
# 216             Borussia Dortmund
# 235             Manchester United
# 245             Manchester United
# 248             Manchester United
# 252             Manchester United
# 259             Manchester United
# 287               Manchester City
# 289               Manchester City
# 329               Manchester City
# 339                  FC Barcelona
# 343                  FC Barcelona
# 346                  FC Barcelona
# 347                  FC Barcelona
# 349                  FC Barcelona
# 350                  FC Barcelona
# 354                  FC Barcelona
# 355                  FC Barcelona
# 367                  FC Barcelona
# 369                  FC Barcelona
# 371                  FC Barcelona
# 372                  FC Barcelona
# ...

# %%
from scraping import scrape_player_img

# %%
players["player_ID"].apply(lambda x: scrape_player_img(x))
