# %%
import copy
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.cm import get_cmap
from formation_map import get_formation
from genetic_algorithm import initialise_individual, select_individuals, mutate_individual, crossover_individuals
from plotting import animate
from speciation import speciate, penalise_overpopulation, get_genetic_diversity

# %%
cmap = get_cmap("viridis")

# %%
# Matplotlib default changes.
mpl.rcParams["figure.facecolor"] = "black"
mpl.rcParams["figure.figsize"] = (12, 10)
mpl.rcParams["axes.facecolor"] = "black"
mpl.rcParams["axes.edgecolor"] = "white"
mpl.rcParams["axes.labelcolor"] = "white"
mpl.rcParams["font.size"] = 14
mpl.rcParams["grid.color"] = "white"
mpl.rcParams["savefig.facecolor"] = "black"
mpl.rcParams["text.color"] = "white"
mpl.rcParams["xtick.color"] = "white"
mpl.rcParams["ytick.color"] = "white"
mpl.rcParams["hatch.color"] = "white"
mpl.rcParams["lines.color"] = "white"
mpl.rcParams["legend.edgecolor"] = "none"
mpl.rc('animation', html='html5')

# %%
np.random.seed(42)

# %%
N_SAMPLES = 10000

N_INDIVIDUALS = 100
N_GENERATIONS = 1000

REPLACE_MUTATION_PROBABILITY = 0.75
SWAP_MUTATION_PROBABILITY = 0.2
SWITCH_MUTATION_PROBABILITY = 0.05
CROSSOVER_PROBABILITY = 0.05

RATING_WEIGHT = 1
CHEMISTRY_WEIGHT = 0.75
PRICE_WEIGHT = 1.5

SPECIATION = True
SPECIATION_THRESHOLD = 2.5

# %%
formation = get_formation("5221")

# %%
sample_individuals = [initialise_individual(formation) for _ in range(N_SAMPLES)]

# %%
ratings = [s.fill().get_rating() for s in sample_individuals]
rating_mean = np.mean(ratings)
rating_std = np.std(ratings)

chemistries = [s.fill().get_chemistry() for s in sample_individuals]
chemistry_mean = np.mean(chemistries)
chemistry_std = np.std(chemistries)

prices = [s.fill().get_price() for s in sample_individuals]
price_mean = np.mean(prices)
price_std = np.std(prices)

# %%
def loss(formation):
    rating = (formation.get_rating() - rating_mean) / rating_std # normalised rating.
    chemistry = (formation.get_chemistry() - chemistry_mean) / chemistry_std # normalised chemistry.
    price = -(formation.get_price() - price_mean) / price_std # negative, normalised price.
    return RATING_WEIGHT * rating + CHEMISTRY_WEIGHT * chemistry + PRICE_WEIGHT * price

# %%
fitness_log = []
rating_log = []
chemistry_log = []
price_log = []
champion_log = []
diversity_log = []

champion = None
population = [initialise_individual(formation) for _ in range(N_INDIVIDUALS)]
for individual in population:
    individual.evaluate(loss)


for i in range(N_GENERATIONS):
    if SPECIATION:
        species = speciate(population, SPECIATION_THRESHOLD)
        diversity_log.append(get_genetic_diversity(species))
        penalise_overpopulation(species)
    population = select_individuals(population)
    for j in range(int(len(population)/2)):
        individuals = population[2*j:2*j+2]
        if np.random.uniform() < CROSSOVER_PROBABILITY:
            crossover_individuals(*individuals, formation)
        for individual in individuals:
            mutate_individual(individual, REPLACE_MUTATION_PROBABILITY, SWAP_MUTATION_PROBABILITY, SWITCH_MUTATION_PROBABILITY)
            individual.evaluate(loss)
    challenger = population[np.argmax(population)]
    new_champion = False
    if not champion or challenger > champion:
        champion = copy.copy(challenger)
        champion_log.append(champion)
        new_champion = True
    champion.fill()
    fitness_log.append(champion.fitness)
    rating_log.append(champion.formation.get_rating())
    chemistry_log.append(champion.formation.get_chemistry())
    price_log.append(champion.formation.get_price())
    if new_champion:   
        print("TURN {}".format(i))
        print("PLAYERS:")
        for k, v in champion.player_map.items():
            print("\t{}: {}".format(k, v))
        print("FITNESS: {0:.2f}".format(champion.fitness))
        print("RATING: {}".format(champion.formation.get_rating()))
        print("CHEMISTRY: {}".format(champion.formation.get_chemistry()))
        print("PRICE: {}".format(int(champion.formation.get_price())))
        print("")
        
print("FINAL CHAMPION")
print("PLAYERS:")
for k, v in champion.player_map.items():
    print("\t{}: {}".format(k, v))
print("FITNESS: {0:.2f}".format(champion.fitness))
print("RATING: {}".format(champion.formation.get_rating()))
print("CHEMISTRY: {}".format(champion.formation.get_chemistry()))
print("PRICE: {}".format(int(champion.formation.get_price())))
print("")
# Out:
# TURN 0
# PLAYERS:
# 	GK: Player(id=12873, name=Gamonal, overall=68, position=GK, price=200, nationality=Chile, league=Campeonato Scotiabank, club=Club Deportes Temuco)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=9382, name=Calisir, overall=67, position=CB, price=300, nationality=Sweden, league=Allsvenskan, club=IFK Göteborg)
# 	CB2: Player(id=10970, name=Pehrsson, overall=64, position=CB, price=500, nationality=Sweden, league=Allsvenskan, club=IK Sirius)
# 	CB3: Player(id=1178, name=Rúben Dias, overall=78, position=CB, price=950, nationality=Portugal, league=Liga NOS, club=SL Benfica)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13907, name=Račić, overall=75, position=CDM, price=500, nationality=Serbia, league=LaLiga Santander, club=Valencia CF)
# 	CM2: Player(id=1248, name=Demirbay, overall=81, position=CAM, price=3000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	LW: Player(id=3837, name=Adomah, overall=75, position=LM, price=550, nationality=Ghana, league=EFL Championship, club=Aston Villa)
# 	ST: Player(id=13820, name=Kušej, overall=59, position=CF, price=200, nationality=Czech Republic, league=Bundesliga 2, club=SG Dynamo Dresden)
# 	RW: Player(id=11190, name=Deacon, overall=62, position=RM, price=1000, nationality=England, league=Scottish Premiership, club=Dundee FC)
# FITNESS: 3.88
# RATING: 779
# CHEMISTRY: 45
# PRICE: 8900
#
# TURN 2
# PLAYERS:
# 	GK: Player(id=12873, name=Gamonal, overall=68, position=GK, price=200, nationality=Chile, league=Campeonato Scotiabank, club=Club Deportes Temuco)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=9382, name=Calisir, overall=67, position=CB, price=300, nationality=Sweden, league=Allsvenskan, club=IFK Göteborg)
# 	CB2: Player(id=10970, name=Pehrsson, overall=64, position=CB, price=500, nationality=Sweden, league=Allsvenskan, club=IK Sirius)
# 	CB3: Player(id=2009, name=Kamara, overall=71, position=CB, price=950, nationality=France, league=Ligue 1 Conforama, club=Olympique de Marseille)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13907, name=Račić, overall=75, position=CDM, price=500, nationality=Serbia, league=LaLiga Santander, club=Valencia CF)
# 	CM2: Player(id=1248, name=Demirbay, overall=81, position=CAM, price=3000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	LW: Player(id=579, name=Welbeck, overall=77, position=LW, price=750, nationality=England, league=Premier League, club=Arsenal)
# 	ST: Player(id=13820, name=Kušej, overall=59, position=CF, price=200, nationality=Czech Republic, league=Bundesliga 2, club=SG Dynamo Dresden)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 4.96
# RATING: 790
# CHEMISTRY: 49
# PRICE: 9050
#
# TURN 6
# PLAYERS:
# 	GK: Player(id=12873, name=Gamonal, overall=68, position=GK, price=200, nationality=Chile, league=Campeonato Scotiabank, club=Club Deportes Temuco)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=10970, name=Pehrsson, overall=64, position=CB, price=500, nationality=Sweden, league=Allsvenskan, club=IK Sirius)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1505, name=Bruma, overall=76, position=CB, price=750, nationality=Holland, league=Bundesliga, club=VfL Wolfsburg)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13907, name=Račić, overall=75, position=CDM, price=500, nationality=Serbia, league=LaLiga Santander, club=Valencia CF)
# 	CM2: Player(id=1248, name=Demirbay, overall=81, position=CAM, price=3000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	LW: Player(id=3837, name=Adomah, overall=75, position=LM, price=550, nationality=Ghana, league=EFL Championship, club=Aston Villa)
# 	ST: Player(id=13820, name=Kušej, overall=59, position=CF, price=200, nationality=Czech Republic, league=Bundesliga 2, club=SG Dynamo Dresden)
# 	RW: Player(id=1635, name=Öztunali, overall=74, position=RM, price=1400, nationality=Germany, league=Bundesliga, club=1. FSV Mainz 05)
# FITNESS: 6.48
# RATING: 796
# CHEMISTRY: 57
# PRICE: 9300
#
# TURN 8
# PLAYERS:
# 	GK: Player(id=12873, name=Gamonal, overall=68, position=GK, price=200, nationality=Chile, league=Campeonato Scotiabank, club=Club Deportes Temuco)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=3050, name=Crespo, overall=72, position=CB, price=800, nationality=Spain, league=Hellas Liga, club=PAOK)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1505, name=Bruma, overall=76, position=CB, price=750, nationality=Holland, league=Bundesliga, club=VfL Wolfsburg)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13907, name=Račić, overall=75, position=CDM, price=500, nationality=Serbia, league=LaLiga Santander, club=Valencia CF)
# 	CM2: Player(id=1248, name=Demirbay, overall=81, position=CAM, price=3000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	LW: Player(id=3837, name=Adomah, overall=75, position=LM, price=550, nationality=Ghana, league=EFL Championship, club=Aston Villa)
# 	ST: Player(id=13820, name=Kušej, overall=59, position=CF, price=200, nationality=Czech Republic, league=Bundesliga 2, club=SG Dynamo Dresden)
# 	RW: Player(id=1635, name=Öztunali, overall=74, position=RM, price=1400, nationality=Germany, league=Bundesliga, club=1. FSV Mainz 05)
# FITNESS: 6.80
# RATING: 804
# CHEMISTRY: 57
# PRICE: 9600
#
# TURN 10
# PLAYERS:
# 	GK: Player(id=2810, name=Didillon, overall=72, position=GK, price=1000, nationality=France, league=Belgium Pro League, club=RSC Anderlecht)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=3381, name=Ceppitelli, overall=72, position=CB, price=700, nationality=Italy, league=Serie A TIM, club=Cagliari)
# 	CB2: Player(id=13401, name=Wheater, overall=70, position=CB, price=2000, nationality=England, league=EFL Championship, club=Bolton Wanderers)
# 	CB3: Player(id=3115, name=Pavard, overall=80, position=CB, price=1200, nationality=France, league=Bundesliga, club=VfB Stuttgart)
# 	RWB: Player(id=197, name=Piszczek, overall=82, position=RB, price=15000, nationality=Poland, league=Bundesliga, club=Borussia Dortmund)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=736, name=Zielinski, overall=81, position=CM, price=15000, nationality=Poland, league=Serie A TIM, club=Napoli)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=7645, name=Zozulya, overall=71, position=ST, price=200, nationality=Ukraine, league=LaLiga 1 I 2 I 3, club=Albacete Bpie)
# 	RW: Player(id=643, name=Walcott, overall=79, position=RM, price=900, nationality=England, league=Premier League, club=Everton)
# FITNESS: 7.55
# RATING: 847
# CHEMISTRY: 52
# PRICE: 54500
#
# TURN 14
# PLAYERS:
# 	GK: Player(id=371, name=Cillessen, overall=81, position=GK, price=800, nationality=Holland, league=LaLiga Santander, club=FC Barcelona)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=3381, name=Ceppitelli, overall=72, position=CB, price=700, nationality=Italy, league=Serie A TIM, club=Cagliari)
# 	CB2: Player(id=1778, name=Diakhaby, overall=77, position=CB, price=2400, nationality=France, league=LaLiga Santander, club=Valencia CF)
# 	CB3: Player(id=7126, name=Willems, overall=69, position=CB, price=400, nationality=France, league=Belgium Pro League, club=Sporting Charleroi)
# 	RWB: Player(id=10475, name=Schröter, overall=66, position=RB, price=300, nationality=Germany, league=3. Liga, club=FSV Zwickau)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=14090, name=Im Seon Yeong, overall=68, position=CM, price=350, nationality=Korea Republic, league=K LEAGUE Classic, club=Jeonbuk Hyundai Motors)
# 	LW: Player(id=16948, name=De Paul, overall=81, position=LM, price=10750, nationality=Argentina, league=Serie A TIM, club=Udinese)
# 	ST: Player(id=1607, name=Embolo, overall=77, position=ST, price=2500, nationality=Switzerland, league=Bundesliga, club=FC Schalke 04)
# 	RW: Player(id=2609, name=Narey, overall=70, position=RM, price=550, nationality=Germany, league=Bundesliga 2, club=Hamburger SV)
# FITNESS: 7.58
# RATING: 822
# CHEMISTRY: 58
# PRICE: 34650
#
# TURN 16
# PLAYERS:
# 	GK: Player(id=1080, name=Vaclík, overall=78, position=GK, price=500, nationality=Czech Republic, league=LaLiga Santander, club=Sevilla FC)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=3381, name=Ceppitelli, overall=72, position=CB, price=700, nationality=Italy, league=Serie A TIM, club=Cagliari)
# 	CB2: Player(id=2019, name=Rakitskyi, overall=80, position=CB, price=1600, nationality=Ukraine, league=Ukrayina Liha, club=Shakhtar Donetsk)
# 	CB3: Player(id=2026, name=Ordets, overall=76, position=CB, price=950, nationality=Ukraine, league=Ukrayina Liha, club=Shakhtar Donetsk)
# 	RWB: Player(id=499, name=Alexander-Arnold, overall=78, position=RB, price=1300, nationality=England, league=Premier League, club=Liverpool)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=4159, name=Cattermole, overall=70, position=CDM, price=600, nationality=England, league=EFL League One, club=Sunderland)
# 	LW: Player(id=13911, name=Dani Olmo, overall=75, position=LM, price=1000, nationality=Spain, league=Liga Hrvatska, club=GNK Dinamo Zagreb)
# 	ST: Player(id=10149, name=Hopper, overall=64, position=ST, price=350, nationality=England, league=EFL League One, club=Southend United)
# 	RW: Player(id=13052, name=Aabid, overall=62, position=RM, price=350, nationality=France, league=Domino’s Ligue 2, club=AS Béziers)
# FITNESS: 7.70
# RATING: 816
# CHEMISTRY: 60
# PRICE: 23250
#
# TURN 18
# PLAYERS:
# 	GK: Player(id=371, name=Cillessen, overall=81, position=GK, price=800, nationality=Holland, league=LaLiga Santander, club=FC Barcelona)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=3381, name=Ceppitelli, overall=72, position=CB, price=700, nationality=Italy, league=Serie A TIM, club=Cagliari)
# 	CB2: Player(id=1778, name=Diakhaby, overall=77, position=CB, price=2400, nationality=France, league=LaLiga Santander, club=Valencia CF)
# 	CB3: Player(id=376, name=Vermaelen, overall=78, position=CB, price=2900, nationality=Belgium, league=LaLiga Santander, club=FC Barcelona)
# 	RWB: Player(id=10475, name=Schröter, overall=66, position=RB, price=300, nationality=Germany, league=3. Liga, club=FSV Zwickau)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=196, name=Witsel, overall=82, position=CM, price=10750, nationality=Belgium, league=Bundesliga, club=Borussia Dortmund)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=10149, name=Hopper, overall=64, position=ST, price=350, nationality=England, league=EFL League One, club=Southend United)
# 	RW: Player(id=2609, name=Narey, overall=70, position=RM, price=550, nationality=Germany, league=Bundesliga 2, club=Hamburger SV)
# FITNESS: 8.37
# RATING: 830
# CHEMISTRY: 61
# PRICE: 37250
#
# TURN 22
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=5042, name=Thelander, overall=73, position=CB, price=800, nationality=Denmark, league=Eredivisie, club=Vitesse)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1249, name=Hübner, overall=80, position=CB, price=2800, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=2322, name=Donk, overall=75, position=CDM, price=950, nationality=Holland, league=Süper Lig, club=Galatasaray SK)
# 	CM2: Player(id=8827, name=Erdmann, overall=66, position=CDM, price=300, nationality=Germany, league=Bundesliga 2, club=1. FC Magdeburg)
# 	LW: Player(id=16624, name=Jacobs, overall=69, position=LM, price=700, nationality=England, league=EFL Championship, club=Wigan Athletic)
# 	ST: Player(id=4517, name=Morris, overall=66, position=ST, price=400, nationality=England, league=EFL Championship, club=Norwich City)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 8.59
# RATING: 793
# CHEMISTRY: 71
# PRICE: 9300
#
# TURN 23
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=8379, name=Meredith, overall=71, position=LB, price=750, nationality=Australia, league=EFL Championship, club=Millwall)
# 	CB1: Player(id=5042, name=Thelander, overall=73, position=CB, price=800, nationality=Denmark, league=Eredivisie, club=Vitesse)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1257, name=Hübner, overall=79, position=CB, price=1200, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=2322, name=Donk, overall=75, position=CDM, price=950, nationality=Holland, league=Süper Lig, club=Galatasaray SK)
# 	CM2: Player(id=14757, name=Jastrzembski, overall=64, position=CAM, price=500, nationality=Germany, league=Bundesliga, club=Hertha BSC)
# 	LW: Player(id=16624, name=Jacobs, overall=69, position=LM, price=700, nationality=England, league=EFL Championship, club=Wigan Athletic)
# 	ST: Player(id=4517, name=Morris, overall=66, position=ST, price=400, nationality=England, league=EFL Championship, club=Norwich City)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 9.43
# RATING: 790
# CHEMISTRY: 77
# PRICE: 7900
#
# TURN 26
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=4905, name=Rúben Ferreira, overall=73, position=LB, price=850, nationality=Portugal, league=Liga NOS, club=CS Marítimo)
# 	CB1: Player(id=12499, name=Galeano, overall=69, position=CB, price=650, nationality=Argentina, league=SAF, club=Club Atlético Aldosivi)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1249, name=Hübner, overall=80, position=CB, price=2800, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	CM2: Player(id=17009, name=Sigurðsson, overall=84, position=CAM, price=23000, nationality=Iceland, league=Premier League, club=Everton)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=7779, name=Schleusener, overall=69, position=ST, price=400, nationality=Germany, league=Bundesliga 2, club=SV Sandhausen)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 9.50
# RATING: 826
# CHEMISTRY: 69
# PRICE: 33900
#
# TURN 27
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=4905, name=Rúben Ferreira, overall=73, position=LB, price=850, nationality=Portugal, league=Liga NOS, club=CS Marítimo)
# 	CB1: Player(id=168, name=Barzagli, overall=84, position=CB, price=3700, nationality=Italy, league=Serie A TIM, club=Juventus)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1249, name=Hübner, overall=80, position=CB, price=2800, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	CM2: Player(id=17009, name=Sigurðsson, overall=84, position=CAM, price=23000, nationality=Iceland, league=Premier League, club=Everton)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=7779, name=Schleusener, overall=69, position=ST, price=400, nationality=Germany, league=Bundesliga 2, club=SV Sandhausen)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 10.09
# RATING: 841
# CHEMISTRY: 69
# PRICE: 36950
#
# TURN 37
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=4905, name=Rúben Ferreira, overall=73, position=LB, price=850, nationality=Portugal, league=Liga NOS, club=CS Marítimo)
# 	CB1: Player(id=4963, name=Nervo, overall=73, position=CB, price=800, nationality=Argentina, league=LIGA Bancomer MX, club=Santos Laguna)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1249, name=Hübner, overall=80, position=CB, price=2800, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13562, name=Alfa Semedo, overall=76, position=CDM, price=700, nationality=Guinea-Bissau, league=Liga NOS, club=SL Benfica)
# 	CM2: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=9162, name=Acquafresca, overall=67, position=ST, price=850, nationality=Italy, league=Raiffeisen Super League, club=FC Sion)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 10.31
# RATING: 820
# CHEMISTRY: 75
# PRICE: 12200
#
# TURN 41
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=4905, name=Rúben Ferreira, overall=73, position=LB, price=850, nationality=Portugal, league=Liga NOS, club=CS Marítimo)
# 	CB1: Player(id=12935, name=Han Pengfei, overall=62, position=CB, price=600, nationality=China PR, league=CSL, club=Guizhou Hengfeng FC)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1249, name=Hübner, overall=80, position=CB, price=2800, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=1255, name=Kaderábek, overall=79, position=RWB, price=950, nationality=Czech Republic, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CM1: Player(id=13499, name=Alfa Semedo, overall=77, position=CDM, price=6600, nationality=Guinea-Bissau, league=Liga NOS, club=SL Benfica)
# 	CM2: Player(id=1628, name=Latza, overall=77, position=CM, price=700, nationality=Germany, league=Bundesliga, club=1. FSV Mainz 05)
# 	LW: Player(id=2259, name=Ricardo Horta, overall=79, position=LM, price=2600, nationality=Portugal, league=Liga NOS, club=SC Braga)
# 	ST: Player(id=9162, name=Acquafresca, overall=67, position=ST, price=850, nationality=Italy, league=Raiffeisen Super League, club=FC Sion)
# 	RW: Player(id=1475, name=Hofmann, overall=78, position=RM, price=950, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# FITNESS: 10.76
# RATING: 808
# CHEMISTRY: 81
# PRICE: 17600
#
# TURN 63
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=484, name=Matip, overall=81, position=CB, price=1000, nationality=Cameroon, league=Premier League, club=Liverpool)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1257, name=Hübner, overall=79, position=CB, price=1200, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=317, name=Walker, overall=84, position=RB, price=90000, nationality=England, league=Premier League, club=Manchester City)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	LW: Player(id=13253, name=Çalhanoğlu, overall=80, position=LW, price=1100, nationality=Turkey, league=Serie A TIM, club=Milan)
# 	ST: Player(id=2188, name=Selke, overall=77, position=ST, price=700, nationality=Germany, league=Bundesliga, club=Hertha BSC)
# 	RW: Player(id=314, name=Bernardo Silva, overall=84, position=RW, price=3000, nationality=Portugal, league=Premier League, club=Manchester City)
# FITNESS: 11.54
# RATING: 861
# CHEMISTRY: 75
# PRICE: 114600
#
# TURN 65
# PLAYERS:
# 	GK: Player(id=1492, name=Nicolas, overall=62, position=GK, price=200, nationality=Germany, league=Bundesliga, club=Borussia Mönchengladbach)
# 	LWB: Player(id=1350, name=Asamoah, overall=80, position=LB, price=15000, nationality=Ghana, league=Serie A TIM, club=Inter)
# 	CB1: Player(id=810, name=Marcano, overall=83, position=CB, price=9500, nationality=Spain, league=Serie A TIM, club=Roma)
# 	CB2: Player(id=3526, name=Gulde, overall=74, position=CB, price=500, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CB3: Player(id=1257, name=Hübner, overall=79, position=CB, price=1200, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	RWB: Player(id=317, name=Walker, overall=84, position=RB, price=90000, nationality=England, league=Premier League, club=Manchester City)
# 	CM1: Player(id=1341, name=Borja Valero, overall=81, position=CAM, price=900, nationality=Spain, league=Serie A TIM, club=Inter)
# 	CM2: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	LW: Player(id=13253, name=Çalhanoğlu, overall=80, position=LW, price=1100, nationality=Turkey, league=Serie A TIM, club=Milan)
# 	ST: Player(id=2188, name=Selke, overall=77, position=ST, price=700, nationality=Germany, league=Bundesliga, club=Hertha BSC)
# 	RW: Player(id=314, name=Bernardo Silva, overall=84, position=RW, price=3000, nationality=Portugal, league=Premier League, club=Manchester City)
# FITNESS: 12.06
# RATING: 863
# CHEMISTRY: 78
# PRICE: 123100
#
# TURN 277
# PLAYERS:
# 	GK: Player(id=420, name=Neuer, overall=90, position=GK, price=74500, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	LWB: Player(id=1521, name=Itter, overall=67, position=LB, price=1100, nationality=Germany, league=Bundesliga, club=VfL Wolfsburg)
# 	CB1: Player(id=4004, name=Schindler, overall=78, position=CB, price=1000, nationality=Germany, league=Premier League, club=Huddersfield Town)
# 	CB2: Player(id=1257, name=Hübner, overall=79, position=CB, price=1200, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CB3: Player(id=1504, name=Uduokhai, overall=76, position=CB, price=850, nationality=Germany, league=Bundesliga, club=VfL Wolfsburg)
# 	RWB: Player(id=3537, name=Kübler, overall=70, position=RB, price=1100, nationality=Germany, league=Bundesliga, club=Sport-Club Freiburg)
# 	CM1: Player(id=1616, name=Serdar, overall=74, position=CM, price=1100, nationality=Germany, league=Bundesliga, club=FC Schalke 04)
# 	CM2: Player(id=3116, name=Didavi, overall=80, position=CAM, price=900, nationality=Germany, league=Bundesliga, club=VfB Stuttgart)
# 	LW: Player(id=3090, name=Gradel, overall=77, position=LM, price=600, nationality=Côte d'Ivoire, league=Ligue 1 Conforama, club=Toulouse Football Club)
# 	ST: Player(id=453, name=Wagner, overall=78, position=ST, price=650, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	RW: Player(id=12254, name=Bassan, overall=71, position=RM, price=900, nationality=Turkey, league=Süper Lig, club=Büyükşehir Belediye Erzurumspor)
# FITNESS: 12.41
# RATING: 840
# CHEMISTRY: 85
# PRICE: 83900
#
# TURN 490
# PLAYERS:
# 	GK: Player(id=1222, name=Benaglio, overall=77, position=GK, price=550, nationality=Switzerland, league=Ligue 1 Conforama, club=AS Monaco Football Club SA)
# 	LWB: Player(id=5105, name=Al Harbi, overall=68, position=LB, price=550, nationality=Saudi Arabia, league=Saudi Professional League, club=Al Ittihad)
# 	CB1: Player(id=3124, name=Baumgartl, overall=76, position=CB, price=950, nationality=Germany, league=Bundesliga, club=VfB Stuttgart)
# 	CB2: Player(id=421, name=Hummels, overall=89, position=CB, price=46000, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	CB3: Player(id=5246, name=Margreitter, overall=74, position=CB, price=550, nationality=Austria, league=Bundesliga, club=1. FC Nürnberg)
# 	RWB: Player(id=1025, name=Bender, overall=82, position=RB, price=1800, nationality=Germany, league=Bundesliga, club=Bayer 04 Leverkusen)
# 	CM1: Player(id=440, name=Tolisso, overall=84, position=CM, price=55000, nationality=France, league=Bundesliga, club=FC Bayern München)
# 	CM2: Player(id=1616, name=Serdar, overall=74, position=CM, price=1100, nationality=Germany, league=Bundesliga, club=FC Schalke 04)
# 	LW: Player(id=445, name=Coman, overall=83, position=LM, price=9000, nationality=France, league=Bundesliga, club=FC Bayern München)
# 	ST: Player(id=453, name=Wagner, overall=78, position=ST, price=650, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	RW: Player(id=2195, name=Esswein, overall=72, position=RM, price=8500, nationality=Germany, league=Bundesliga, club=Hertha BSC)
# FITNESS: 12.45
# RATING: 857
# CHEMISTRY: 82
# PRICE: 124650
#
# TURN 493
# PLAYERS:
# 	GK: Player(id=7800, name=Rensing, overall=73, position=GK, price=750, nationality=Germany, league=Bundesliga, club=Fortuna Düsseldorf)
# 	LWB: Player(id=1603, name=Oczipka, overall=78, position=LWB, price=2500, nationality=Germany, league=Bundesliga, club=FC Schalke 04)
# 	CB1: Player(id=421, name=Hummels, overall=89, position=CB, price=46000, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	CB2: Player(id=1277, name=Akpoguma, overall=75, position=CB, price=1000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CB3: Player(id=1588, name=Sané, overall=81, position=CB, price=4000, nationality=Senegal, league=Bundesliga, club=FC Schalke 04)
# 	RWB: Player(id=1025, name=Bender, overall=82, position=RB, price=1800, nationality=Germany, league=Bundesliga, club=Bayer 04 Leverkusen)
# 	CM1: Player(id=1591, name=Omar Mascarell, overall=80, position=CDM, price=2800, nationality=Spain, league=Bundesliga, club=FC Schalke 04)
# 	CM2: Player(id=3116, name=Didavi, overall=80, position=CAM, price=900, nationality=Germany, league=Bundesliga, club=VfB Stuttgart)
# 	LW: Player(id=922, name=Vitolo, overall=81, position=LM, price=1200, nationality=Spain, league=LaLiga Santander, club=Atlético Madrid)
# 	ST: Player(id=6099, name=Mcbean, overall=64, position=ST, price=950, nationality=United States, league=Major League Soccer, club=Colorado Rapids)
# 	RW: Player(id=2713, name=Lennon, overall=77, position=RM, price=600, nationality=England, league=Premier League, club=Burnley)
# FITNESS: 12.67
# RATING: 860
# CHEMISTRY: 81
# PRICE: 62500
#
# TURN 494
# PLAYERS:
# 	GK: Player(id=7800, name=Rensing, overall=73, position=GK, price=750, nationality=Germany, league=Bundesliga, club=Fortuna Düsseldorf)
# 	LWB: Player(id=1603, name=Oczipka, overall=78, position=LWB, price=2500, nationality=Germany, league=Bundesliga, club=FC Schalke 04)
# 	CB1: Player(id=421, name=Hummels, overall=89, position=CB, price=46000, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	CB2: Player(id=1277, name=Akpoguma, overall=75, position=CB, price=1000, nationality=Germany, league=Bundesliga, club=TSG 1899 Hoffenheim)
# 	CB3: Player(id=1588, name=Sané, overall=81, position=CB, price=4000, nationality=Senegal, league=Bundesliga, club=FC Schalke 04)
# 	RWB: Player(id=1025, name=Bender, overall=82, position=RB, price=1800, nationality=Germany, league=Bundesliga, club=Bayer 04 Leverkusen)
# 	CM1: Player(id=1591, name=Omar Mascarell, overall=80, position=CDM, price=2800, nationality=Spain, league=Bundesliga, club=FC Schalke 04)
# 	CM2: Player(id=3116, name=Didavi, overall=80, position=CAM, price=900, nationality=Germany, league=Bundesliga, club=VfB Stuttgart)
# 	LW: Player(id=922, name=Vitolo, overall=81, position=LM, price=1200, nationality=Spain, league=LaLiga Santander, club=Atlético Madrid)
# 	ST: Player(id=12640, name=Mushekwi, overall=69, position=ST, price=200, nationality=Zimbabwe, league=CSL, club=Dalian Yifang FC)
# 	RW: Player(id=2713, name=Lennon, overall=77, position=RM, price=600, nationality=England, league=Premier League, club=Burnley)
# FITNESS: 12.87
# RATING: 865
# CHEMISTRY: 81
# PRICE: 61750
#
# TURN 500
# PLAYERS:
# 	GK: Player(id=12804, name=Gonzalez, overall=68, position=GK, price=200, nationality=Chile, league=Campeonato Scotiabank, club=Unión La Calera)
# 	LWB: Player(id=3194, name=Albornoz, overall=71, position=LB, price=1000, nationality=Chile, league=Bundesliga, club=Hannover 96)
# 	CB1: Player(id=3124, name=Baumgartl, overall=76, position=CB, price=950, nationality=Germany, league=Bundesliga, club=VfB Stuttgart)
# 	CB2: Player(id=421, name=Hummels, overall=89, position=CB, price=46000, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	CB3: Player(id=13279, name=Raúl, overall=80, position=CB, price=1200, nationality=Brazil, league=Liga NOS, club=SC Braga)
# 	RWB: Player(id=1025, name=Bender, overall=82, position=RB, price=1800, nationality=Germany, league=Bundesliga, club=Bayer 04 Leverkusen)
# 	CM1: Player(id=440, name=Tolisso, overall=84, position=CM, price=55000, nationality=France, league=Bundesliga, club=FC Bayern München)
# 	CM2: Player(id=1616, name=Serdar, overall=74, position=CM, price=1100, nationality=Germany, league=Bundesliga, club=FC Schalke 04)
# 	LW: Player(id=445, name=Coman, overall=83, position=LM, price=9000, nationality=France, league=Bundesliga, club=FC Bayern München)
# 	ST: Player(id=453, name=Wagner, overall=78, position=ST, price=650, nationality=Germany, league=Bundesliga, club=FC Bayern München)
# 	RW: Player(id=2195, name=Esswein, overall=72, position=RM, price=8500, nationality=Germany, league=Bundesliga, club=Hertha BSC)
# FITNESS: 13.41
# RATING: 857
# CHEMISTRY: 88
# PRICE: 125400

# %%
with open("../input/champion_log.p", "wb") as f:
    pickle.dump(champion_log, f)

# %%
x = np.arange(0, N_GENERATIONS)
fig, axs = plt.subplots(4, 1, figsize=(16, 12))

for ax, data, title in zip(axs, [fitness_log, rating_log, chemistry_log, price_log], ["Fitness", "Rating", "Chemistry", "Price"]):
    ax.plot(x, data, linewidth=3, color=cmap(1.))
    ax.set_title(label=title)
    ax.set_xlabel("Generation")    
    
fig.tight_layout()

plt.savefig("../images/fitness_curve.png", dpi=120)
