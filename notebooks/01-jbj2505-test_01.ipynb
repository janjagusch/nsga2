# %%
import os
import urllib.request
import requests
import bs4 as bs
import pandas as pd

# %%
def _get_player_url(player_id):
    return "https://www.futbin.com/19/player/{}".format(player_id)


def _get_player_img_url(player_id):
    url = _get_player_url(player_id)
    r = requests.get(url)
    s = bs.BeautifulSoup(r.content, "html.parser")
    img_url = s.find("img", {"id": "player_pic", "class": "pcdisplay-picture-width"})["src"]
    return img_url


def _get_player_img(player_id):
    url = _get_player_img_url(player_id)
    user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    headers = {'User-Agent': user_agent, }
    request = urllib.request.Request(url, None, headers)
    response = urllib.request.urlopen(request)
    img = response.read()
    return img


def scrape_player_img(player_id, filepath="../input/pictures/"):
#     stored_players = pd.Series(os.listdir(filepath)).str.replace(".png", "")
#     if player_id not in stored_players:
    filename = "{}.png".format(player_id)
    img = _get_player_img(player_id)
    with open(os.path.join(filepath, filename), "wb") as f:
        f.write(img)

# %%
_URL = "https://www.futbin.com/19/player/16370/Lee%20Watkins/"

# %%
r = requests.get(_URL)

# %%
s = bs.BeautifulSoup(r.content, "html.parser")

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>			<html class="ie ie8"> <![endif]-->
# <!--[if IE 9]>			<html class="ie ie9"> <![endif]-->
# <html>
#  <head>
#   <!-- Basic -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="FIFA Ultimate Team 19 Player - Lee Watkins | Find the lowest BIN, Prices, Stats, Details, Graphs and more!" name="description"/>
#   <meta content="FUTBIN" name="author"/>
#   <meta content="app-id=1080465358" name="apple-itunes-app"/>
#   <meta content="app-id=com.futbin" name="google-play-app"/>
#   <!--    <meta name="viewport" content="width=device-width, initial-scale=1.0">-->
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <title>
#    FIFA 19 Player - Lee Watkins | FUTBIN
#   </title>
#   <script>
#    window.jQuery || document.write('<script src="https://cdn.futbin.com/design/js/jquery.min.js"><\/script>')
#       //  window.jQuery || document.write('<script src="https://code.jquery.com/jquery-3.3.1.min.js"><\/script>')
#   </script>
#   <!--    <script-->
#   <!--            src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js"-->
#   <!--            integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU="-->
#   <!--            crossorigin="anonymous"></script>-->
#   <link href="https://cdn.futbin.com/design/css/main.css?v=190918175217" rel="stylesheet"/>
#   <link href="https://cdn.futbin.com/design/css/mdb.css?v=081218095053" rel="stylesheet"/>
#   <!-- -->
#   <!--        <link rel="stylesheet" href="-->
#   <!--/design/css/mdb.css?v=-->
#   <!--"/>-->
#   <!-- -->
#   <!--        <link rel="stylesheet" href="-->
#   <!--/design/css/mdb.min.css?v=-->
#   <!--"/>-->
#   <!-- -->
#   <!--    <link rel="stylesheet" href="-->
#   <!--/design/css/custom.min.css?v=-->
#   <!--"/>-->
#   <script src="https://cdn.futbin.com/design/js/main.js?v=190918175213" type="text/javascript">
#   </script>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-57x57.png?v=17" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-60x60.png?v=17" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-72x72.png?v=17" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-76x76.png?v=17" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-114x114.png?v=17" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-120x120.png?v=17" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-144x144.png?v=17" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-152x152.png?v=17" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://cdn.futbin.com/design/img/favic/apple-icon-180x180.png?v=17" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://cdn.futbin.com/design/img/favic/android-icon-192x192.png?17" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://cdn.futbin.com/design/img/favic/favicon-32x32.png?v=17" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.futbin.com/design/img/favic/favicon-96x96.png?v=17" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://cdn.futbin.com/design/img/favic/favicon-16x16.png?v=17" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://cdn.futbin.com/design/img/favic/manifest.json?v=17" rel="manifest"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="https://cdn.futbin.com/design/img/favic/ms-icon-144x144.png?v=17" name="msapplication-TileImage"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <!--[if IE]>
#     <link rel="stylesheet" href="https://cdn.futbin.com/design/css/ie.css">
#     <![endif]-->
#   <!--[if lte IE 8]>
#     <script src="https://cdn.futbin.com/design/vendor/respond.js"></script>
#
#     <![endif]-->
#   <link href="https://cdn.futbin.com/design/css/hover-min.css?v=190918175218" rel="stylesheet">
#    <link href="https://cdn.futbin.com/design/css/quill/quill.snow.min.css?v=190918175216" rel="stylesheet">
#     <link href="https://cdn.futbin.com/design/css/jquery.rateyo.min.css?v=190918175217" rel="stylesheet">
#      <link href="https://cdn.futbin.com/design/css/plugins/scrubber.css?v=190918175216" rel="stylesheet">
#       <script>
#        (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-51927210-1', 'futbin.com', {'sampleRate': 2});
#         ga('send', 'pageview');
#       </script>
#       <!--    <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>-->
#       <!--    <script>-->
#       <!--        (adsbygoogle = window.adsbygoogle || []).push({-->
#       <!--            google_ad_client: "ca-pub-1184080919266052",-->
#       <!--            enable_page_level_ads: true-->
#       <!--        });-->
#       <!--    </script>-->
#       <!-- Venatus Market Ad-Manager (futbin.com) -->
#       <script>
#        (function(){
#                 document.write('<div id="vmv3-ad-manager" style="display:none"></div>');
#                 document.getElementById("vmv3-ad-manager").innerHTML='<iframe id="vmv3-frm" src="javascript:false" width="0" height="0" data-mode="scan" data-site-id="58e515dc46e0fb0001c45588"></iframe>';
#                 var a=document.getElementById("vmv3-frm");
#                 a=a.contentWindow?a.contentWindow:a.contentDocument;a.document.open();
#                 a.document.write('<script src="https://hb.vntsm.com/v3/live/ad-manager.min.js" type="text/javascript" async>'+'</scr'+'ipt>');
#                 a.document.close()
#             })();
#       </script>
#       <!-- / Venatus Market Ad-Manager (futbin.com) -->
#       <meta content="86c38dfbd8a1aada765d648af62da4250dfea5e98d59a72925beddbbcb93c5514f588f5135e830626423f3a1d4b26f96e780296a45d7d69f4649c05b9fac025c" name="general_csrf-name"/>
#       <meta content="d8b1f5398ff846fbb9b4d6b9feb709c06b64026368158847f8359cfa6623c5f85d75bfd0a9f1de9c28a430ca04c75d641c2f293fa92e63c2c3685ce34ea4ca87" name="general_csrf-value"/>
#       <!-- Begin Cookie Consent plugin by Silktide - http://silktide.com/cookieconsent -->
#       <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.css" rel="stylesheet" type="text/css">
#        <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.1.0/cookieconsent.min.js">
#        </script>
#        <script>
#         window.addEventListener("load", function(){
#                 window.cookieconsent.initialise({
#                     "palette": {
#                         "popup": {
#                             "background": "#eaf7f7",
#                             "text": "#5c7291"
#                         },
#                         "button": {
#                             "background": "#55cca2",
#                             "text": "#ffffff"
#                         }
#                     },
#                     "content": {
#                         "href": "https://www.futbin.com/privacy"
#                     }
#                 })});
#        </script>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="">
#   <div id="fb-root">
#   </div>
#   <div data-cdn-url="https://cdn.futbin.com" data-image-url="https://cdn.futbin.com" data-main-year="19" id="web-info" style="display: none;">
#   </div>
#   <script>
#    window.cdn_url = "https://cdn.futbin.com";
#     window.main_year = "19";
#   </script>
#   <header>
#    <!--MOBILE NAV -->
#    <style>
#     @media (min-width: 990px) {
#             #slide-out {
#                 display: none;
#             }
#         }
#    </style>
#    <script>
#     $( document ).ready(function() {
#              // SideNav Button Initialization
#              $(".button-collapse-2").sideNav();
# // SideNav Scrollbar Initialization
#              var sideNavScrollbar = document.querySelector('.custom-scrollbar-2');
#              Ps.initialize(sideNavScrollbar);
#          });
#    </script>
#    <!-- Sidebar navigation -->
#    <div class="side-nav side-nav-mobile fut-19-cyan-pink-gradient fixed" id="slide-out">
#     <div class="row co-12 text-center pb-0 mb-0" style="height: 50px;">
#      <div class="col-6 pt-2">
#       <li class="list-inline-item">
#        <div class="switch">
#         <label>
#          <i class="icon-sun pr-1">
#          </i>
#          <input class="theme-switch notxtselect hide" type="checkbox"/>
#          <span class="lever">
#          </span>
#          <i class="icon-moon pl-1">
#          </i>
#         </label>
#        </div>
#       </li>
#      </div>
#      <!-- langs -->
#      <div class="col-6 pt-2">
#       <li class="list-inline-item dropdown" id="lang-nav-item">
#        <div aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle waves-effect waves-light" data-toggle="dropdown" id="navbarDropdownMenuLink">
#         <span>
#          <img alt="uk" src="https://cdn.futbin.com/design/img/flag/24/UnitedKingdom.png" style="width:20px;"/>
#         </span>
#        </div>
#        <div aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu dropdown-menu-right dropdown-default" style="height: 300px; overflow-y: scroll;">
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="en" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="uk" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/UnitedKingdom.png" style="width:20px;"/>
#           English
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="fr" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="fr" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/France.png" style="width:20px;"/>
#           français / French
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="es" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="es" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Spain.png" style="width:20px;"/>
#           Español / Spanish
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="zh" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="cn" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/China.png" style="width:20px;"/>
#           中文 / Chinese
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="ar" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="ar" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/SaudiArabia.png" style="width:20px;"/>
#           العربية / Arabic
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="de" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="de" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Germany.png" style="width:20px;"/>
#           Deutsch / German
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="da" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="da" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Denmark.png" style="width:20px;"/>
#           Dansk / Danish
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="nl" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="nl" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Netherlands.png" style="width:20px;"/>
#           Dutch / Nederlands
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="it" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="it" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Italy.png" style="width:20px;"/>
#           Italiano / Italian
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="he" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="he" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Israel.png" style="width:20px;"/>
#           עברית / Hebrew
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="pt" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="pt" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Brazil.png" style="width:20px;"/>
#           Português / Portuguese
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="ru" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="ru" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Russian.png" style="width:20px;"/>
#           Россия / Russian
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="cs" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="cs" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Czech_Republic.png" style="width:20px;"/>
#           Česká / Czech
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="ja" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="ja" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/japan.png" style="width:20px;"/>
#           日本語 / Japanese
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="tr" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="tr" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Turkey.png" style="width:20px;"/>
#           Türkçe / Turkish
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="nn" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="nn" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Norway.png" style="width:20px;"/>
#           Norge / Norwegian
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="pl" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="pl" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Poland.png" style="width:20px;"/>
#           POLSKA / Polish
#          </span>
#         </a>
#         <a class="dropdown-item waves-effect waves-light myLang" data-lang="se" href="#" style="    color: inherit; height: 30px; line-height: 30px;">
#          <span>
#           <img alt="se" class="nav-lang-img" data-original="https://cdn.futbin.com/design/img/flag/24/Sweden.png" style="width:20px;"/>
#           Sverige / Swedish
#          </span>
#         </a>
#        </div>
#       </li>
#      </div>
#     </div>
#     <ul class="custom-scrollbar-2">
#      <li class="pl-3 pt-3">
#       <a class="waves-effect text-white d-inline" href="/account/login">
#        <i class="fa fa-sign-in">
#        </i>
#        Login
#       </a>
#       <a class="waves-effect text-white d-inline ml-1" href="/account/register">
#        <i class="fa fa-users">
#        </i>
#        Register
#       </a>
#      </li>
#      <!-- Side navigation links -->
#      <li>
#       <ul class="collapsible collapsible-accordion mt-0" style="padding-bottom: 200px;">
#        <!-- CHANGE PLATFORM -->
#        <li>
#         <a class="collapsible-header waves-effect arrow-r">
#          <img class="nav-bar-platform" src="https://cdn.futbin.com/design/img/logos/small/ps_white.png"/>
#          Change Platform
#          <i class="fa fa-angle-down rotate-icon">
#          </i>
#         </a>
#         <div class="collapsible-body">
#          <ul>
#           <li>
#            <a class="change-platform pl-4" data-platform="ps4" href="javascript:void(0)" style="padding: 5px;">
#             <img class="nav-bar-platform" src="https://cdn.futbin.com/design/img/logos/small/ps_white.png" style="width: 20px; position: relative; top: -2px;"/>
#             Playstation 4
#            </a>
#           </li>
#           <li>
#            <a class="change-platform pl-4" data-platform="xone" href="javascript:void(0)" style="padding: 5px;">
#             <img class="nav-bar-platform" src="https://cdn.futbin.com/design/img/logos/small/xbox_white.png" style="width: 20px; position: relative; top: -2px;"/>
#             XBOX ONE
#            </a>
#           </li>
#           <li>
#            <a class="change-platform pl-4" data-platform="pc" href="javascript:void(0)" style="padding: 5px;">
#             <img class="nav-bar-platform" src="https://cdn.futbin.com/design/img/logos/small/pc_white.png" style="width: 20px; position: relative; top: -2px;"/>
#             PC
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="collapsible-header waves-effect arrow-r">
#          <i class="icon-fire ">
#          </i>
#          Live
#          <i class="fa fa-angle-down rotate-icon">
#          </i>
#         </a>
#         <div class="collapsible-body">
#          <ul>
#           <li>
#            <a class="waves-effect" href="/fut-live-scores">
#             <i class="icon-feed">
#             </i>
#             FUT Live Scores
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/otw">
#             <i class="icon-eye">
#             </i>
#             OTW Watch
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/totw-predictions">
#             <i class="icon-trophy4">
#             </i>
#             TOTW Contenders
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/potm-contenders">
#             <i class="icon-racing">
#             </i>
#             POTM Contenders
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <li>
#         <a class="waves-effect" href="/division-rivals/division">
#          <img src="/design/img/rivals_small_19.png" style="width: 20px;"/>
#          Division Rivals
#         </a>
#        </li>
#        <li>
#         <a class="waves-effect" href="/champions/leaderboard">
#          <img alt="p" src="/design/img/champs_small_19.png" style="width: 22px;"/>
#          FUT Champions
#         </a>
#        </li>
#        <li>
#         <a class="waves-effect" href="/picks">
#          <img alt="p" src="/design/img/shapes/picks/picks-icon.png" style="width: 22px;"/>
#          Picks
#         </a>
#        </li>
#        <!-- PLAYER MENU  -->
#        <li>
#         <a class="collapsible-header waves-effect arrow-r">
#          <i class="icon-collaboration">
#          </i>
#          Players
#          <i class="fa fa-angle-down rotate-icon">
#          </i>
#         </a>
#         <div class="collapsible-body">
#          <ul>
#           <li>
#            <a class="waves-effect" href="/19/players">
#             Players
#            </a>
#           </li>
#           <!--                                 <li><a href="/-->
#           <!--/world-cup/players" class="waves-effect">FIFA WC 18 -->
#           <!--</a></li>-->
#           <!--                                 <li><a href="/-->
#           <!--/rating-refresh" class="waves-effect"><img  style="width: 15px;" alt="rr_logo" class="sbc_nav" src="-->
#           <!--icons/rr/-->
#           <!--/r_refresh_nav.png?v=1"> -->
#           <!-- -->
#           <!--</a></li>-->
#           <!--                                 <li><a href="/-->
#           <!--/skill-upgrades" class="waves-effect"> <img  style="width: 15px;" alt="rr_logo" class="sbc_nav" src="-->
#           <!--icons/rr/-->
#           <!--/r_refresh_nav.png?v=1"> -->
#           <!-- -->
#           <!--</a></li>-->
#           <li>
#            <a class="waves-effect" href="/19/pgp">
#             <i class="icon-stats-bars">
#             </i>
#             PGP
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/popular">
#             <i class="icon-fire text-danger">
#             </i>
#             Popular
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/latest">
#             <span class="pulse-pink">
#             </span>
#             FIFA 19 New Players
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/special/Transfers">
#             <i class="icon-tab">
#             </i>
#             Transfers
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <!-- Mews  link -->
#        <li>
#         <a class="waves-effect" href="/news">
#          <i class="icon-magazine nav-small-icons">
#          </i>
#          Articles
#         </a>
#        </li>
#        <!-- Builder Battles link -->
#        <li>
#         <a class="waves-effect" href="/squad-builder">
#          <i class="icon-hammer-wrench nav-small-icon">
#          </i>
#          Squad Builder
#         </a>
#        </li>
#        <!-- Draft  link -->
#        <li>
#         <a class="waves-effect" href="/draft-simulator">
#          <i class="icon-stack-user nav-small-icons">
#          </i>
#          Draft
#         </a>
#        </li>
#        <!-- SBC MENU  -->
#        <li>
#         <a class="collapsible-header waves-effect arrow-r">
#          <img alt="sbc_logo" class="sbc_nav" src="https://cdn.futbin.com/design/img/sbc_small_color.png"/>
#          SBC
#          <i class="fa fa-angle-down rotate-icon">
#          </i>
#         </a>
#         <div class="collapsible-body">
#          <ul>
#           <li>
#            <a class="waves-effect" href="/squad-building-challenges">
#             <i class="icon-station2">
#             </i>
#             Active Challenges
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/stc/challenges">
#             <i class="icon-menu2">
#             </i>
#             Challenges List Filter
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/stc/squads">
#             <i class="icon-users4">
#             </i>
#             Community SBC Solutions
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/stc/cheapest">
#             <i class="icon-podium2">
#             </i>
#             Cheapest Players By Rating
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/sbc-rating-combinations">
#             <i class="icon-cube3">
#             </i>
#             SBC Rating Combinations
#            </a>
#           </li>
#           <h6 class="dropdown-header text-white">
#            Club
#           </h6>
#           <li>
#            <a class="waves-effect" href="/stc/analyze">
#             <i class="icon-binoculars2">
#             </i>
#             SBC Club Analyzer
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#        <!-- WC MENU  -->
#        <!--                     <li><a class="collapsible-header waves-effect arrow-r">  <img  style="width: 13px; position: relative; top: -1px;" src="/design/img/shapes/wc/18/wc_logo_2.png">-->
#        <!-- <i class="fa fa-angle-down rotate-icon"></i></a>-->
#        <!--                         <div class="collapsible-body">-->
#        <!--                             <ul>-->
#        <!--                                 <li><a href="/world-cup" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/players" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/upgrades" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/latest" class="waves-effect">-->
#        <!-- </a></li>-->
#        <!--                                 <li><a href="/world-cup-builder" class="waves-effect"><i class="icon-hammer-wrench nav-small-icons"></i> -->
#        <!-- </a></li>-->
#        <!--                                 <li><a href="/world-cup-builder/draft" class="waves-effect"><img style="width: 20px; position: relative; top:-2px;" src="/design/img/shapes/wc/18/draft/draft-card-small-78.png" /> WC -->
#        <!-- </a></li>-->
#        <!--                                 <li><a href="/world-cup/squad-building-challenges" class="waves-effect"><img alt="" style="width: 20px;" src="/design/img/shapes/wc/18/sbc_small.png"> SBC</a></li>-->
#        <!--                                 <li><a href="/world-cup/kits" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/stadiums" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/groups" class="waves-effect">-->
#        <!--</a></li>-->
#        <!--                                 <li><a href="/world-cup/schedule" class="waves-effect">-->
#        <!--</a></li>-->
#        <!-- -->
#        <!--                             </ul>-->
#        <!--                         </div>-->
#        <!--                     </li>-->
#        <!-- Squad Battles link -->
#        <li>
#         <a class="waves-effect" href="/squad-battles/points">
#          <img src="/design/img/sb_small_19.png" style="width: 20px;"/>
#          Squad Battles
#         </a>
#        </li>
#        <!-- Packs MENU  -->
#        <li>
#         <a class="collapsible-header waves-effect arrow-r">
#          <i class="icon-stack4">
#          </i>
#          Packs
#          <i class="fa fa-angle-down rotate-icon">
#          </i>
#         </a>
#         <div class="collapsible-body">
#          <ul>
#           <li>
#            <a class="waves-effect" href="/19/packs">
#             <i class="icon-stack4">
#             </i>
#             Packs
#            </a>
#           </li>
#           <li>
#            <a class="waves-effect" href="/packs/leaderboard">
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </div>
#   </header>
#  </body>
# </html>
# Leaderboard
# <!-- Market MENU  -->
# <li>
#  <a <i="" class="icon-stats-dots desk-nav-img">
#  </a>
# </li>
# Market
# <i class="fa fa-angle-down rotate-icon">
# </i>
# <div class="collapsible-body">
#  <ul>
#   <li>
#    <a class="waves-effect" href="/market">
#     <i class="icon-chart">
#     </i>
#     Index100
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/Special">
#     <img alt="Market Gold" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/goldinform.png?v=2"/>
#     IndexSpecial
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/OnesToWatch">
#     <img alt="Market OTW" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/otw.png?v=2"/>
#     IndexOnesToWatch
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/Gold">
#     <img alt="Market IF" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/goldrnif.png?v=2"/>
#     IndexGold
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/Silver">
#     <img alt="Market Silver" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/silverrnif.png?v=2"/>
#     IndexSilver
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/Icons">
#     <img alt="Market Icons" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/icon.png?v=2"/>
#     IndexIcons
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/UCL">
#     <img alt="Market UCL" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/ucl_rare.png?v=2"/>
#     IndexUCL
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/UCLLive">
#     <img alt="Market Live UCL" class="market-nav-card" src="https://cdn.futbin.com/content/fifa19/img/cards/tiny/ucl_live.png?v=2"/>
#     IndexLiveUCL
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/86">
#     Index86
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/85">
#     Index85
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/84">
#     Index84
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/83">
#     Index83
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/82">
#     Index82
#    </a>
#   </li>
#   <li>
#    <a class="waves-effect" href="/market/81">
#     Index81
#    </a>
#   </li>
#  </ul>
# </div>
# <!-- SBC MENU  -->
# <li>
#  <a class="collapsible-header waves-effect arrow-r">
#   <i class="icon-collaboration desk-nav-img">
#   </i>
#   Squads
#   <i class="fa fa-angle-down rotate-icon">
#   </i>
#  </a>
#  <div class="collapsible-body">
#   <ul>
#    <li>
#     <a class="waves-effect" href="/community/squads/builder">
#      FUT 19 Community Squads
#     </a>
#    </li>
#    <li>
#     <a class="waves-effect" href="/community/squads/draft">
#      FUT 19 Community Drafts
#     </a>
#    </li>
#    <!--                                 <li><a href="/tots" class="waves-effect"> <img alt="Market Gold" class="market-nav-card" src="/content/fifa19/img/cards/tiny/totsg.png?v=2"> TOTS</a></li>-->
#    <li>
#     <a class="waves-effect" href="/squads">
#      All TOTWs
#     </a>
#    </li>
#    <li class="m-0 p-0">
#     <a class="waves-effect" data-original-title="07.12.18" data-placement="right" data-rel="tooltip" href="/19/totw/TOTGS" style="background: #071237; color: #db00ff !important;">
#      TOTGS
#     </a>
#    </li>
#    <li class="m-0 p-0">
#     <a class="waves-effect" data-original-title="05.12.18" data-placement="right" data-rel="tooltip" href="/19/totw/TOTW12" style="background: #000000; color: #ffeb7e !important;">
#      TOTW12
#     </a>
#    </li>
#    <li class="m-0 p-0">
#     <a class="waves-effect" data-original-title="28.11.18" data-placement="right" data-rel="tooltip" href="/19/totw/TOTW11" style="background: #000000; color: #ffeb7e !important;">
#      TOTW11
#     </a>
#    </li>
#    <li class="m-0 p-0">
#     <a class="waves-effect" data-original-title="21.11.18" data-placement="right" data-rel="tooltip" href="/19/totw/TOTW10" style="background: #000000; color: #ffeb7e !important;">
#      TOTW10
#     </a>
#    </li>
#    <li class="m-0 p-0">
#     <a class="waves-effect" data-original-title="14.11.18" data-placement="right" data-rel="tooltip" href="/19/totw/TOTW9" style="background: #000000; color: #ffeb7e !important;">
#      TOTW9
#     </a>
#    </li>
#   </ul>
#  </div>
# </li>
# <!-- TOOLS MENU  -->
# <li>
#  <a class="collapsible-header waves-effect arrow-r">
#   <i class="icon-wrench desk-nav-img">
#   </i>
#   Tools
#   <i class="fa fa-angle-down rotate-icon">
#   </i>
#  </a>
#  <div class="collapsible-body">
#   <ul>
#    <li>
#     <a class="waves-effect" href="/user/club">
#      <i class="icon-tshirt">
#      </i>
#      Import
#     </a>
#    </li>
#    <li>
#     <a class="waves-effect" href="/squad-calculator">
#      <i class="icon-calculator4 text-pink">
#      </i>
#      Squad Calculator
#     </a>
#    </li>
#    <li>
#     <a class="waves-effect" href="/stats-calculator">
#      <i class="icon-calculator2">
#      </i>
#      Stats Calculator
#     </a>
#    </li>
#    <li>
#     <a class="waves-effect" href="/calculator">
#      <i class="icon-calculator3">
#      </i>
#      FUT Calculator
#     </a>
#    </li>
#    <li>
#     <a class="waves-effect" href="/fut-card-creator">
#      <i class="icon-screwdriver2">
#      </i>
#      FUT Card Creator
#     </a>
#    </li>
#   </ul>
#  </div>
# </li>
# <!--Social-->
# <li>
#  <ul class="social">
#   <li>
#    <a class="icons-sm fb-ic" href="https://www.facebook.com/pages/biz/FUTBIN-1438762766367500/" target="_blank">
#     <i class="fa fa-facebook">
#     </i>
#    </a>
#   </li>
#   <li>
#    <a class="icons-sm tw-ic" href="https://twitter.com/FUTBIN" target="_blank">
#     <i class="fa fa-twitter">
#     </i>
#    </a>
#   </li>
#  </ul>
# </li>
# <li class="pt-3">
#  <a class="waves-effect btn btn-sm btn-danger" href="/user/logout" style="height: auto; line-height: unset;">
#   <i class="fa fa-power-off">
#   </i>
#   Logout
#  </a>
# </li>
# <!-- SBC MENU  -->
# <!--                     <li><a class="collapsible-header waves-effect arrow-r"><i class="fa fa-envelope-o"></i> Contact me<i class="fa fa-angle-down rotate-icon"></i></a>-->
# <!--                         <div class="collapsible-body">-->
# <!--                             <ul>-->
# <!--                                 <li><a href="ggggggg" class="waves-effect">FAQ</a></li>-->
# <!--                             </ul>-->
# <!--                         </div>-->
# <!--                     </li>-->
# <!--/. Side navigation links -->
# <div class="sidenav-bg rgba-white-slight">
# </div>
# <!--/. Sidebar navigation -->
# <!--Navbar-->
# <nav class="navbar navbar-expand-lg navbar-dark primary-color fixed-top pb-1" id="desk-nav" style="max-width: 100vw;">
#  <div class="container">
#   <!-- Navbar brand -->
#   <a class="navbar-brand mr-1" href="/">
#    <img alt="" height="30" src="https://cdn.futbin.com/design/img/small-futbin-logo.png?v=5"/>
#   </a>
#   <!-- Collapse button -->
#   <button aria-controls="basicExampleNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#basicExampleNav" data-toggle="collapse" type="button">
#    <span class="navbar-toggler-icon">
#    </span>
#   </button>
#   <!-- SideNav slide-out button -->
#   <a class=" button-collapse-2 nav-mobile-item" data-activates="slide-out" href="#">
#    <i class="fa fa-bars text-white">
#    </i>
#   </a>
#   <form class="form-inline form-mobile-search col-8 px-0 m-0">
#    <div class="md-form my-0">
#     <input aria-label="Search" autocomplete="off" class=" nav_search_bar_mobile w-100 form-control mr-sm-2 px-0 m-0" id="nav_search_bar_mobile" placeholder="Search..." type="text"/>
#    </div>
#   </form>
#   <!-- SideNav slide-out button -->
#   <a class="nav-mobile-item-close-search" href="javascript:void(0)" style="display: none;">
#    <i class="icon-cross2 text-white">
#    </i>
#   </a>
#   <!--/ home logo-->
#   <a class="mobile-futbin-logo nav-mobile-item" href="/">
#    <img alt="" height="30" src="https://cdn.futbin.com/design/img/small-futbin-logo.png?v=5"/>
#   </a>
#   <!-- Choose lang  -->
#   <div class="collapse navbar-collapse" id="main-site-nav">
#    <!-- Links -->
#    <ul class="navbar-nav mr-auto">
#     <li class="nav-item dropdown">
#      <a aria-expanded="false" aria-haspopup="true" class="nav-link " href="/players" id="navbarDropdownPlayersLink">
#       Players
#      </a>
#      <ul aria-labelledby="navbarDropdownPlayersLink" class="dropdown-menu">
#       <li>
#        <a class="dropdown-item" href="/19/players">
#         FIFA 19 Players
#        </a>
#       </li>
#       <!--                           <li><a href="/-->
#       <!--/rating-refresh" class="dropdown-item"><img  style="width: 15px;" alt="rr_logo" class="sbc_nav" src="-->
#       <!--icons/rr/-->
#       <!--/r_refresh_nav.png?v=1"> -->
#       <!-- -->
#       <!--</a></li>-->
#       <!--                           <li><a href="/-->
#       <!--/skill-upgrades" class="dropdown-item"><img  style="width: 15px;" alt="rr_logo" class="sbc_nav" src="-->
#       <!--icons/rr/-->
#       <!--/r_refresh_nav.png?v=1"> -->
#       <!-- -->
#       <!--</a></li>-->
#       <li>
#        <a class="dropdown-item" href="/19/pgp">
#         <i class="icon-stats-bars">
#         </i>
#         PGP
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/popular">
#         <i class="icon-fire popular-nav">
#         </i>
#         Popular
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/latest">
#         <i class="icon-new new-players-nav">
#         </i>
#         New FIFA 19 Players
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/picks">
#         <img alt="sbc_logo" class="sbc_nav desk-nav-img" src="/design/img/shapes/picks/picks-icon.png" style="width: 20px;"/>
#         Picks
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/special/Transfers">
#         <i class="icon-tab">
#         </i>
#         Transfers
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/priceranges">
#         <img src="/design/img/coins_bin.png" style="width: 15px;"/>
#         Price Range Updates
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/squads">
#         TOTWs
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/leagues">
#         FIFA 19 Leagues
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/clubs">
#         FIFA 19 Clubs
#        </a>
#       </li>
#       <li>
#        <a class="dropdown-item" href="/nations">
#         FIFA 19 Nations
#        </a>
#       </li>
#       <li class="dropdown-submenu">
#        <a class="dropdown-item dropdown-toggle" href="#">
#         FUT 18
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/18/players">
#           Players
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/squad-builder">
#           Squad Builder
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/draft-simulator">
#           Draft Simulator
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/special/Transfers">
#           <i class="icon-tab">
#           </i>
#           Transfers
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/skill-upgrades">
#           <img alt="rr_logo" class="sbc_nav" src="https://cdn.futbin.com/design/img/icons/rr/18/r_refresh_nav.png?v=1" style="width: 15px;"/>
#           Skill Upgrades
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/rating-refresh">
#           <img alt="rr_logo" class="sbc_nav" src="https://cdn.futbin.com/design/img/icons/rr/18/r_refresh_nav.png?v=1g" style="width: 15px;"/>
#           Ratings Refresh
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/squads">
#           TOTWs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/leagues">
#           Leagues
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/clubs">
#           Clubs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/nations">
#           Nations
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/club_items/kits">
#           Kits
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/club_items/badges">
#           Badges
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/club_items/balls">
#           Balls
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/18/club_items/stadiums">
#           Stadiums
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown-submenu">
#        <a class="dropdown-item dropdown-toggle" href="#">
#         <img src="/design/img/shapes/wc/18/wc_logo_2.png" style=" width: 10px;"/>
#         FUT 18 WC
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/world-cup">
#           Main
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/playerss">
#           Players
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/upgrades">
#           <i class="icon-tab">
#           </i>
#           Upgrades
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/latest">
#           Latest
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup-builder">
#           Squad Builder
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup-builder/draft">
#           Draft Simulator
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/squad-building-challenges">
#           <img src="/design/img/shapes/wc/18/sbc_small.png" style="width: 10px;"/>
#           SBC
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/kits">
#           Kits
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/groups">
#           Groups
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/world-cup/stadiums">
#           Stadiums
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown-submenu">
#        <a class="dropdown-item dropdown-toggle" href="#">
#         FUT 17
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/17/players">
#           Players
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/special/Transfers">
#           <i class="icon-tab">
#           </i>
#           Transfers
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/skill-upgrades">
#           <img alt="rr_logo" class="sbc_nav" src="https://cdn.futbin.com/design/img/r_refresh_nav.png" style="width: 15px;"/>
#           Skill Upgrades
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/rating-refresh">
#           <img alt="rr_logo" class="sbc_nav" src="https://cdn.futbin.com/design/img/r_refresh_nav.png" style="width: 15px;"/>
#           Ratings Refresh
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/squads">
#           TOTWs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/leagues">
#           Leagues
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/clubs">
#           Clubs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/nations">
#           Nations
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/club_items/kits">
#           Kits
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/club_items/badges">
#           Badges
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/club_items/balls">
#           Balls
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/17/club_items/stadiums">
#           Stadiums
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown-submenu">
#        <a class="dropdown-item dropdown-toggle" href="#">
#         FUT 16
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/16/players">
#           Players
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/squads">
#           TOTWs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/leagues">
#           Leagues
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/clubs">
#           Clubs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/nations">
#           Nations
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/club_items/kits">
#           Kits
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/club_items/badges">
#           Badges
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/club_items/balls">
#           Balls
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/16/club_items/stadiums">
#           Stadiums
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown-submenu">
#        <a class="dropdown-item dropdown-toggle" href="#">
#         FUT 15
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a class="dropdown-item" href="/15/players">
#           Players
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/15/squads">
#           TOTWs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/15/leagues">
#           Leagues
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/15/clubs">
#           Clubs
#          </a>
#         </li>
#         <li>
#          <a class="dropdown-item" href="/15/nations">
#           Nations
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li class="nav-item dropdown">
#      <a class="nav-link" data-close-others="false" data-delay="0" data-hover="dropdown" href="/squad-building-challenges" id="navbarDropdownSbc">
#       <img alt="sbc_logo" class="sbc_nav desk-nav-img" src="https://cdn.futbin.com/design/img/sbc_small_color.png"/>
#      </a>
#      <div aria-labelledby="navbarDropdownSbc" class="dropdown-menu dropdown-primary">
#       <a class="dropdown-item" href="/squad-building-challenges">
#        <i class="icon-station2">
#        </i>
#        Active Challenges
#       </a>
#       <a class="dropdown-item" href="/stc/challenges">
#        <i class="icon-menu2">
#        </i>
#        Challenges List Filter
#       </a>
#       <a class="dropdown-item" href="/stc/squads">
#        <i class="icon-users4">
#        </i>
#        Community SBC Solutions
#       </a>
#       <a class="dropdown-item" href="/stc/cheapest">
#        <i class="icon-podium2">
#        </i>
#        Cheapest Players By Rating
#       </a>
#       <a class="dropdown-item" href="/sbc-rating-combinations">
#        <i class="icon-cube3">
#        </i>
#        SBC Rating Combinations
#       </a>
#       <h6 class="dropdown-header">
#        Club
#       </h6>
#       <a class="dropdown-item" href="/stc/analyze">
#        <i class="icon-binoculars2">
#        </i>
#        SBC Club Analyzer
#       </a>
#      </div>
#     </li>
#     <li class="nav-item">
#      <a class="nav-link" data-original-title="Division Rivals" data-placement="bottom" data-toggle="tooltip" href="/division-rivals/division">
#       <img class="desk-nav-img" src="https://cdn.futbin.com/design/img/rivals_small_19.png" style="width: 20px;"/>
#      </a>
#     </li>
#     <li class="nav-item">
#      <a class="nav-link" data-original-title="FUT Champions" data-placement="bottom" data-toggle="tooltip" href="/champions/leaderboard">
#       <img alt="sbc_logo" class="sbc_nav desk-nav-img" src="/design/img/champs_small_19.png" style="width: 20px;"/>
#      </a>
#     </li>
#     <li class="nav-item">
#      <a class="nav-link" data-original-title="Squad Battles" data-placement="bottom" data-toggle="tooltip" href="/squad-battles/points">
#       <img class="desk-nav-img" src="https://cdn.futbin.com/design/img/sb_small_19.png" style="width: 20px;"/>
#      </a>
#     </li>
#     <!--                   <li class="nav-item">-->
#     <!--                       <a class="nav-link" href="/division-rivals"><img style="width: 20px;" class="desk-nav-img" src="-->
#     <!--rivals_small_19.png"> </a>-->
#     <!--                   </li>-->
#     <li class="nav-item">
#      <a class="nav-link" data-original-title="Draft Simulator" data-placement="bottom" data-toggle="tooltip" href="/draft-simulator">
#       <img class="desk-nav-img" src="https://cdn.futbin.com/design/img/draft_small_19.png" style="width: 20px;"/>
#      </a>
#     </li>
#     <li class="nav-item dropdown">
#      <a class="nav-link" data-close-others="false" data-delay="0" data-hover="dropdown" href="/squad-builder" id="navbarDropdownPacks">
#       <i class="icon-hammer-wrench nav-small-icons desk-nav-img">
#       </i>
#       Builder
#      </a>
# ...
#      </div>
#      <div class="gen-modal-players-year-header">
#       FIFA 16
#      </div>
#      <div class="divider_w">
#      </div>
#      <div id="gen-modal-players-year-row">
#      </div>
#      <div class="gen-modal-players-year-header">
#       FIFA 15
#      </div>
#      <div class="divider_w">
#      </div>
#      <div id="gen-modal-players-year-row">
#      </div>
#     </div>
#     <div class="modal-footer">
#      <button class="btn btn-danger " data-dismiss="modal" type="button">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="calculater_display" id="cal" style="display: none; width: 250px;">
#  <div style="text-align:center;background:#55CCA2;font-size:18px;color:#FFFFFF;padding:3%;border-bottom: 3px solid #319270;  font-family: EA;">
#   FUT TAX Calculator
#  </div>
#  <div style="padding:4%;padding-bottom:0;">
#   <div class="form-group">
#    <input class="form-control tax-price" maxlength="16" oninput="calculatorAtMenu()" placeholder="" style="width:100%" type="text"/>
#   </div>
#   <div class="form-group" style="border:1px solid #ACACAC;border-radius:2%;padding:0.5%;padding-top:0;">
#    <table class="table table-condensed table-striped" style="margin-bottom:0px;">
#     <tbody>
#      <tr>
#       <td>
#        Tax:
#       </td>
#       <td class="tax" style="text-align:right;">
#       </td>
#      </tr>
#      <tr style="background-color:#FFFFFF;">
#       <td>
#        Net:
#       </td>
#       <td class="tax-total" style="text-align:right;">
#       </td>
#      </tr>
#      <tr>
#       <td>
#        Sell for:
#       </td>
#       <td class="tax-sell" style="text-align:right;">
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <div class="form-group" style="text-align:center;margin-top:1%; ">
#    <button class="fav_menus text1" onclick="clearInput()">
#     Clear
#    </button>
#    <button class="fav_menus_danger text1 cal">
#     Close
#    </button>
#   </div>
#  </div>
# </div>
# <!-- Footer -->
# <footer class="page-footer font-small unique-color-dark">
#  <div style="background-color: #55cca2;">
#   <div class="container">
#    <!-- Grid row-->
#    <div class="row py-4 d-flex align-items-center">
#     <!-- Grid column -->
#     <div class="col-md-6 col-lg-5 text-center text-md-left mb-4 mb-md-0">
#      <h6 class="mb-0">
#       Contact us on social networks!
#      </h6>
#     </div>
#     <!-- Grid column -->
#     <!-- Grid column -->
#     <div class="col-md-6 col-lg-7 text-center text-md-right">
#      <!-- Facebook -->
#      <a class="fb-ic" href="https://www.facebook.com/FUTBIN-1438762766367500/">
#       <i class="fa fa-facebook white-text mr-4">
#       </i>
#      </a>
#      <!-- Twitter -->
#      <a class="tw-ic" href="https://twitter.com/FUTBIN">
#       <i class="fa fa-twitter white-text mr-4">
#       </i>
#      </a>
#      <!--Instagram-->
#      <!--                    <a class="ins-ic">-->
#      <!--                        <i class="fa fa-instagram white-text"> </i>-->
#      <!--                    </a>-->
#     </div>
#     <!-- Grid column -->
#    </div>
#    <!-- Grid row-->
#   </div>
#  </div>
#  <!-- Footer Links -->
#  <div class="container text-center text-md-left mt-5">
#   <!-- Grid row -->
#   <div class="row mt-3">
#    <!-- Grid column -->
#    <div class="col ">
#     <!-- Content -->
#     <h6 class="text-uppercase font-weight-bold">
#      Latest Squads
#     </h6>
#     <hr class="primary-color accent-2 mb-2 mt-0 d-inline-block mx-auto" style="width: 60px;"/>
#     <p>
#      <a data-original-title="07.12.18" data-placement="right" data-rel="tooltip" href="/totw/TOTGS">
#       TOTGS
#      </a>
#     </p>
#     <p>
#      <a data-original-title="05.12.18" data-placement="right" data-rel="tooltip" href="/totw/TOTW12">
#       TOTW12
#      </a>
#     </p>
#     <p>
#      <a data-original-title="28.11.18" data-placement="right" data-rel="tooltip" href="/totw/TOTW11">
#       TOTW11
#      </a>
#     </p>
#     <p>
#      <a data-original-title="21.11.18" data-placement="right" data-rel="tooltip" href="/totw/TOTW10">
#       TOTW10
#      </a>
#     </p>
#     <p>
#      <a data-original-title="14.11.18" data-placement="right" data-rel="tooltip" href="/totw/TOTW9">
#       TOTW9
#      </a>
#     </p>
#    </div>
#    <!-- Grid column -->
#    <!-- Grid column -->
#    <div class="col ">
#     <!-- Links -->
#     <h6 class="text-uppercase font-weight-bold">
#      Useful Links
#     </h6>
#     <hr class="primary-color accent-2 mb-2 mt-0 d-inline-block mx-auto" style="width: 60px;"/>
#     <p>
#      <a href="/squad-builder">
#       Squad Builder
#      </a>
#     </p>
#     <p>
#      <a href="/squad-building-challenges">
#       SBC
#      </a>
#     </p>
#     <p>
#      <a href="/draft-simulator">
#       Draft
#      </a>
#     </p>
#     <p>
#      <a href="/players">
#       FIFA 19 Players
#      </a>
#     </p>
#    </div>
#    <!-- Grid column -->
#    <!-- Grid column -->
#    <div class="col">
#     <!-- Links -->
#     <h6 class="text-uppercase font-weight-bold">
#      FUTBIN Application
#     </h6>
#     <hr class="primary-color accent-2 mb-2 mt-0 d-inline-block mx-auto" style="width: 60px;"/>
#     <p>
#      <a href="https://play.google.com/store/apps/details?id=com.futbin">
#       <i aria-hidden="true" class="fa fa-android">
#       </i>
#       FUTBIN For Android
#      </a>
#     </p>
#     <p>
#      <a href="https://itunes.apple.com/us/app/futbin/id1080465358?mt=8">
#       <i aria-hidden="true" class="fa fa-apple">
#       </i>
#       FUTBIN For iOS
#      </a>
#     </p>
#     <p>
#      <a href="/app">
#       More Details
#      </a>
#     </p>
#    </div>
#    <!-- Grid column -->
#    <!-- Grid column -->
#    <div class="col-4 ">
#     <!-- Links -->
#     <h6 class="text-uppercase font-weight-bold">
#      Languages
#     </h6>
#     <hr class="primary-color accent-2 mb-2 mt-0 d-inline-block mx-auto" style="width: 60px;"/>
#     <ul class="list-unstyled footer-lang-list">
#      <li>
#       <a class="myLang" data-lang="en" href="#" tabindex="-1">
#        <span>
#         <img alt="uk" src="https://cdn.futbin.com/design/img/flag/24/UnitedKingdom.png" style="width:20px;"/>
#        </span>
#        English
#       </a>
#       <a class="myLang" data-lang="fr" href="#" tabindex="-1">
#        <span>
#         <img alt="fr" src="https://cdn.futbin.com/design/img/flag/24/France.png" style="width:20px;"/>
#         French
#        </span>
#       </a>
#       <a class="myLang" data-lang="es" href="#" tabindex="-1">
#        <span>
#         <img alt="es" src="https://cdn.futbin.com/design/img/flag/24/Spain.png" style="width:20px;"/>
#         Spanish
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="myLang" data-lang="zh" href="#" tabindex="-1">
#        <span>
#         <img alt="cn" src="https://cdn.futbin.com/design/img/flag/24/China.png" style="width:20px;"/>
#         Chinese
#        </span>
#       </a>
#       <a class="myLang" data-lang="ar" href="#" tabindex="-1">
#        <span>
#         <img alt="ar" src="https://cdn.futbin.com/design/img/flag/24/SaudiArabia.png" style="width:20px;"/>
#         Arabic
#        </span>
#       </a>
#       <a class="myLang" data-lang="de" href="#" tabindex="-1">
#        <span>
#         <img alt="de" src="https://cdn.futbin.com/design/img/flag/24/Germany.png" style="width:20px;"/>
#         German
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="myLang" data-lang="da" href="#" tabindex="-1">
#        <span>
#         <img alt="da" src="https://cdn.futbin.com/design/img/flag/24/Denmark.png" style="width:20px;"/>
#         Danish
#        </span>
#       </a>
#       <a class="myLang" data-lang="nl" href="#" tabindex="-1">
#        <span>
#         <img alt="nl" src="https://cdn.futbin.com/design/img/flag/24/Netherlands.png" style="width:20px;"/>
#         Nederlands
#        </span>
#       </a>
#       <a class="myLang" data-lang="it" href="#" tabindex="-1">
#        <span>
#         <img alt="it" src="https://cdn.futbin.com/design/img/flag/24/Italy.png" style="width:20px;"/>
#         Italian
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="myLang" data-lang="he" style="cursor: pointer;" tabindex="-1">
#        <span>
#         <img alt="he" src="https://cdn.futbin.com/design/img/flag/24/Israel.png" style="width:20px;"/>
#         Hebrew
#        </span>
#       </a>
#       <a class="myLang" data-lang="pt" href="#" tabindex="-1">
#        <span>
#         <img alt="pt" src="https://cdn.futbin.com/design/img/flag/24/Brazil.png" style="width:20px;"/>
#         Portuguese
#        </span>
#       </a>
#       <a class="myLang" data-lang="ru" href="#" tabindex="-1">
#        <span>
#         <img alt="ru" src="https://cdn.futbin.com/design/img/flag/24/Russian.png" style="width:20px;"/>
#         Russian
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="myLang" data-lang="cs" href="#" tabindex="-1">
#        <span>
#         <img alt="cs" src="https://cdn.futbin.com/design/img/flag/24/Czech_Republic.png" style="width:20px;"/>
#         Czech
#        </span>
#       </a>
#       <a class="myLang" data-lang="ja" href="#" tabindex="-1">
#        <span>
#         <img alt="ja" src="https://cdn.futbin.com/design/img/flag/24/japan.png" style="width:20px;"/>
#         Japanese
#        </span>
#       </a>
#       <a class="myLang" data-lang="tr" href="#" tabindex="-1">
#        <span>
#         <img alt="tr" src="https://cdn.futbin.com/design/img/flag/24/Turkey.png" style="width:20px;"/>
#         Turkish
#        </span>
#       </a>
#      </li>
#      <li>
#       <a class="myLang" data-lang="nn" href="#" tabindex="-1">
#        <span>
#         <img alt="nn" src="https://cdn.futbin.com/design/img/flag/24/Norway.png" style="width:20px;"/>
#         Norwegian
#        </span>
#       </a>
#       <a class="myLang" data-lang="pl" href="#" tabindex="-1">
#        <span>
#         <img alt="pl" src="https://cdn.futbin.com/design/img/flag/24/Poland.png" style="width:20px;"/>
#         Polish
#        </span>
#       </a>
#       <a class="myLang" data-lang="se" href="#" tabindex="-1">
#        <span>
#         <img alt="se" src="https://cdn.futbin.com/design/img/flag/24/Sweden.png" style="width:20px;"/>
#         Swedish
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <!-- Grid column -->
#   </div>
#   <!-- Grid row -->
#  </div>
#  <!-- Footer Links -->
#  <!-- Copyright -->
#  <div class="footer-copyright text-center py-3">
#   © 2018 Copyright
#   <a href="https://www.futbin.com">
#    FUTBIN.com
#   </a>
#   All FIFA assets are property of EA Sports.
#  </div>
#  <!-- Copyright -->
# </footer>
# <!-- Footer -->
# <div style="display: none;">
# </div>
# <script src="https://cdn.futbin.com/design/js/chemstyle/19/chemstyle.min.js?v=251118190220">
# </script>
# <script src="https://cdn.futbin.com/design/js/highCharts/highstock.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/highCharts/exporting.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/highCharts/highcharts-more.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/plugins/scrubber.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/comments.js?v=141118120526">
# </script>
# <script src="https://cdn.futbin.com/design/js/pages/player.min.js?v=081218095053">
# </script>
# <script src="https://cdn.futbin.com/design/js/quill/quill.min.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/plugins/justgage-1.2.2/justgage.min.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/plugins/justgage-1.2.2/raphael-2.1.4.min.min.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/jquery.rateyo.min.js?v=190918175213">
# </script>
# <script src="https://cdn.futbin.com/design/js/custom.min.js?v=101118101721" type="text/javascript">
# </script>
# <script src="https://cdn.futbin.com/design/js/material/mdb.min.js?v=190918175213" type="text/javascript">
# </script>
# <script src="https://cdn.futbin.com/design/js/sidenav.js?v=190918175213" type="text/javascript">
# </script>
# <script>
#  $("a[data-rel]").tooltip();
# </script>
# <script>
#  var currentGen = getCookie('gentype');
#     if (currentGen == "oldgen") {
#         var genText = "Switch to Console(PS4 and XB1)";
#     } else if (currentGen == "newgen") {
#         genText = "Switch to PC";
#     }
#     $('.slicknav_menu').prepend('<span><a class="slick_home" href="/"><i class="fa fa-home fa-2x" aria-hidden="true"></i> </a></span>');
# </script>
# <!-- Start of StatCounter Code for Default Guide -->
# <script type="text/javascript">
#  var sc_project=9767571;
#     var sc_invisible=1;
#     var sc_security="2fe138da";
#     var sc_https=1;
#     var sc_remove_link=1;
#     var scJsHost = (("https:" == document.location.protocol) ?
#         "https://secure." : "http://www.");
#     document.write("<sc"+"ript type='text/javascript' src='" +
#         scJsHost+
#         "statcounter.com/counter/counter.js'></"+"script>");
# </script>
# <noscript>
#  <div class="statcounter">
#   <img alt="WebAnalytics" class="statcounter" src="//c.statcounter.com/9767571/0/2fe138da/1/"/>
#  </div>
# </noscript>
# <!-- End of StatCounter Code for Default Guide -->
# <!-- Button trigger modal -->
# <!--<button type="button" class="btn btn-primary" data-toggle="modal" data-target="#report-comment-modal">-->
# <!--    Launch demo modal-->
# <!--</button>-->
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="report-comment-modal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-notify modal-danger" role="document">
#   <div class="modal-content">
#    <div class="modal-header">
#     <h5 class="modal-title text-white" id="exampleModalLabel">
#      Report
#     </h5>
#     <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#      <span aria-hidden="true">
#       ×
#      </span>
#     </button>
#    </div>
#    <div class="modal-body">
#     <h6>
#      Please report a comment in the next cases:
#     </h6>
#     <ul>
#      <li>
#       Contains any racism or violence
#      </li>
#      <li>
#       Spam
#      </li>
#      <li>
#       There's a Bug
#      </li>
#      <li>
#       Anything else that you find disturbing
#      </li>
#     </ul>
#    </div>
#    <div class="modal-footer justify-content-center">
#     <button class="btn btn-outline-danger" data-dismiss="modal" type="button">
#      Cancel
#     </button>
#     <button class="btn btn-danger" data-comment-id="" id="report-comment-modal-btn" type="button">
#      <i class="icon-warning">
#      </i>
#      Report
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
# <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="rules-comment-modal" role="dialog" tabindex="-1">
#  <div class="modal-dialog modal-notify modal-danger" role="document">
#   <div class="modal-content">
#    <div class="modal-header">
#     <h5 class="modal-title text-white" id="exampleModalLabel">
#      Dos and don'ts
#     </h5>
#     <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#      <span aria-hidden="true">
#       ×
#      </span>
#     </button>
#    </div>
#    <div class="modal-body">
#     <p>
#      We have decided to add comments to facilitate communication and interaction between FUTBIN users. We believe and hope that we can build a stable community in FUTBIN and that comments will be a part of it. We have created a guideline, which will help you to understand how to use our comments system.
#     </p>
#     <h6 class="text-success">
#      Do's:
#     </h6>
#     <ul>
#      <li>
#       Comment your opinion on things, and/or add valuable information
#      </li>
#      <li>
#       Reply to other comments in a respectful manner
#      </li>
#      <li>
#       Report comments which are offensive
#      </li>
#     </ul>
#     <h6 class="text-danger">
#      Don'ts
#     </h6>
#     <ul>
#      <li>
#       Use any racism
#      </li>
#      <li>
#       Attack or threat other users. It's ok to disagree with others, but keep the comments polite and respectful
#      </li>
#      <li>
#       Spam or post spam content
#      </li>
#      <li>
#       Link other websites
#      </li>
#     </ul>
#     <div class="text-center text-danger">
#      Violation of the above rules can lead to account closure.
#     </div>
#    </div>
#    <div class="modal-footer justify-content-center">
#     <button class="btn btn-outline-danger" data-dismiss="modal" type="button">
#      Close
#     </button>
#    </div>
#   </div>
#  </div>
# </div>
# <!--</div>-->
# <div id="site-backdrop" style="display: none;">
# </div>
