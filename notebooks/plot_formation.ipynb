# %%
import pickle
from plotting import animate, plot_formation

# %%
position_coordinate_map = {
    'GK': (0.5, 0.15),
    'LB': (0.1, 0.35),
    'CB1': (0.35, 0.35),
    'CB2': (0.65, 0.35),
    'RB': (0.9, 0.35),
    'CM1': (0.3, 0.6),
    'CM2': (0.5, 0.6),
    'CM3': (0.7, 0.6),
    'LW': (0.1, 0.85),
    'ST': (0.5, 0.85),
    'RW': (0.9, 0.85)
}

# %%
position_coordinate_map = {
    'GK': (0.5, 0.125),
    'LWB': (0.1, 0.375),
    'CB1': (0.3, 0.375),
    'CB2': (0.5, 0.375),
    'CB3': (0.7, 0.375),
    'RWB': (0.9, 0.375),
    'CM1': (0.4, 0.625),
    'CM2': (0.6, 0.625),
    'LW': (0.1, 0.875),
    'ST': (0.5, 0.875),
    'RW': (0.9, 0.875)
}

# %%
with open("../input/champion_log.p", "rb") as f:
    champion_log = pickle.load(f)

# %%
for k, v in champion_log[-1].player_map.items():
    print("{}: {}".format(k, v))
# Out:
# GK: Player(id=910, name=Adán, overall=83, position=GK, price=1200, nationality=Spain, league=LaLiga Santander, club=Atlético Madrid)
# LWB: Player(id=1627, name=Aarón Martín, overall=77, position=LB, price=1100, nationality=Spain, league=Bundesliga, club=1. FSV Mainz 05)
# CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# CB2: Player(id=617, name=Nacho Fernández, overall=83, position=CB, price=2100, nationality=Spain, league=LaLiga Santander, club=Real Madrid)
# CB3: Player(id=355, name=Piqué, overall=87, position=CB, price=18250, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# RWB: Player(id=361, name=Sergi Roberto, overall=84, position=RB, price=3000, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# CM1: Player(id=428, name=Thiago, overall=86, position=CM, price=14750, nationality=Spain, league=Bundesliga, club=FC Bayern München)
# ...

# %%
plot_formation(champion_log[-1].fill(), position_coordinate_map)

# %%
animate(champion_log, position_coordinate_map, gif=False)
