# %%
import copy
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.cm import get_cmap
from formation_map import get_formation
from genetic_algorithm import initialise_individual, select_individuals, mutate_individual, crossover_individuals
from plotting import animate
from speciation import speciate, penalise_overpopulation, get_genetic_diversity

# %%
cmap = get_cmap("viridis")

# %%
# Matplotlib default changes.
mpl.rcParams["figure.facecolor"] = "black"
mpl.rcParams["figure.figsize"] = (12, 10)
mpl.rcParams["axes.facecolor"] = "black"
mpl.rcParams["axes.edgecolor"] = "white"
mpl.rcParams["axes.labelcolor"] = "white"
mpl.rcParams["font.size"] = 14
mpl.rcParams["grid.color"] = "white"
mpl.rcParams["savefig.facecolor"] = "black"
mpl.rcParams["text.color"] = "white"
mpl.rcParams["xtick.color"] = "white"
mpl.rcParams["ytick.color"] = "white"
mpl.rcParams["hatch.color"] = "white"
mpl.rcParams["lines.color"] = "white"
mpl.rcParams["legend.edgecolor"] = "none"
mpl.rc('animation', html='html5')

# %%
np.random.seed(42)

# %%
N_SAMPLES = 10000

N_INDIVIDUALS = 100
N_GENERATIONS = 1000

REPLACE_MUTATION_PROBABILITY = 0.75
SWAP_MUTATION_PROBABILITY = 0.2
SWITCH_MUTATION_PROBABILITY = 0.05
CROSSOVER_PROBABILITY = 0.05

RATING_WEIGHT = 10
CHEMISTRY_WEIGHT = 10
PRICE_WEIGHT = 0.1
N_BARCELONA_PLAYERS_WEIGHT = 1000

SPECIATION = False
SPECIATION_THRESHOLD = 2.5

# %%
formation = get_formation("433")

# %%
def loss(formation):
    rating = min(85 * 11, formation.get_rating()) * RATING_WEIGHT
    chemistry = min(80, formation.get_chemistry()) * CHEMISTRY_WEIGHT
    price = -formation.get_price() * PRICE_WEIGHT
    n_barcelona_players = min(1, len([p for p in formation.slots.values() if p.player.data["club"] == "FC Barcelona"])) * N_BARCELONA_PLAYERS_WEIGHT
    return rating + chemistry + price + n_barcelona_players

# %%
fitness_log = []
rating_log = []
chemistry_log = []
price_log = []
champion_log = []
diversity_log = []

champion = None
population = [initialise_individual(formation) for _ in range(N_INDIVIDUALS)]
for individual in population:
    individual.evaluate(loss)


for i in range(N_GENERATIONS):
    if SPECIATION:
        species = speciate(population, SPECIATION_THRESHOLD)
        diversity_log.append(get_genetic_diversity(species))
        penalise_overpopulation(species)
    population = select_individuals(population)
    for j in range(int(len(population)/2)):
        individuals = population[2*j:2*j+2]
        if np.random.uniform() < CROSSOVER_PROBABILITY:
            crossover_individuals(*individuals, formation)
        for individual in individuals:
            mutate_individual(individual, REPLACE_MUTATION_PROBABILITY, SWAP_MUTATION_PROBABILITY, SWITCH_MUTATION_PROBABILITY)
            individual.evaluate(loss)
    challenger = population[np.argmax(population)]
    new_champion = False
    if not champion or challenger > champion:
        champion = copy.copy(challenger)
        champion_log.append(champion)
        new_champion = True
    champion.fill()
    fitness_log.append(champion.fitness)
    rating_log.append(champion.formation.get_rating())
    chemistry_log.append(champion.formation.get_chemistry())
    price_log.append(champion.formation.get_price())
    if new_champion:   
        print("TURN {}".format(i))
        print("PLAYERS:")
        for k, v in champion.player_map.items():
            print("\t{}: {}".format(k, v))
        print("FITNESS: {0:.2f}".format(champion.fitness))
        print("RATING: {}".format(champion.formation.get_rating()))
        print("CHEMISTRY: {}".format(champion.formation.get_chemistry()))
        print("PRICE: {}".format(int(champion.formation.get_price())))
        print("")
        
print("FINAL CHAMPION")
print("PLAYERS:")
for k, v in champion.player_map.items():
    print("\t{}: {}".format(k, v))
print("FITNESS: {0:.2f}".format(champion.fitness))
print("RATING: {}".format(champion.formation.get_rating()))
print("CHEMISTRY: {}".format(champion.formation.get_chemistry()))
print("PRICE: {}".format(int(champion.formation.get_price())))
print("")
# Out:
# TURN 0
# PLAYERS:
# 	GK: Player(id=15364, name=Hawsawi, overall=55, position=GK, price=200, nationality=Saudi Arabia, league=Saudi Professional League, club=Al Fayha)
# 	LB: Player(id=10577, name=Pogatetz, overall=68, position=CB, price=500, nationality=Austria, league=Österreichische Fußball-Bundesliga, club=LASK Linz)
# 	CB1: Player(id=13640, name=Brown, overall=65, position=LB, price=200, nationality=England, league=EFL League One, club=Coventry City)
# 	CB2: Player(id=3028, name=Callsen-Bracker, overall=71, position=CB, price=600, nationality=Germany, league=Bundesliga, club=FC Augsburg)
# 	RB: Player(id=6996, name=Carraça, overall=71, position=RB, price=800, nationality=Portugal, league=Liga NOS, club=Boavista FC)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8500.00
# RATING: 775
# CHEMISTRY: 45
# PRICE: 7000
#
# TURN 1
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=10577, name=Pogatetz, overall=68, position=CB, price=500, nationality=Austria, league=Österreichische Fußball-Bundesliga, club=LASK Linz)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=4201, name=Velanas, overall=63, position=CM, price=200, nationality=Holland, league=Eredivisie, club=FC Utrecht)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8630.00
# RATING: 792
# CHEMISTRY: 47
# PRICE: 7600
#
# TURN 3
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=10577, name=Pogatetz, overall=68, position=CB, price=500, nationality=Austria, league=Österreichische Fußball-Bundesliga, club=LASK Linz)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8720.00
# RATING: 809
# CHEMISTRY: 45
# PRICE: 8200
#
# TURN 5
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=13409, name=Li Xuepeng, overall=70, position=LB, price=400, nationality=China PR, league=CSL, club=Guangzhou Evergrande Taobao)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	RB: Player(id=623, name=Odriozola, overall=80, position=RB, price=1200, nationality=Spain, league=LaLiga Santander, club=Real Madrid)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=15626, name=Mišlov, overall=63, position=CDM, price=200, nationality=Croatia, league=Österreichische Fußball-Bundesliga, club=SKN St. Pölten)
# 	LW: Player(id=9731, name=Bahebri, overall=67, position=LM, price=200, nationality=Saudi Arabia, league=Saudi Professional League, club=Al Shabab)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8760.00
# RATING: 807
# CHEMISTRY: 45
# PRICE: 7600
#
# TURN 6
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=2682, name=Tonelli, overall=77, position=CB, price=800, nationality=Italy, league=Serie A TIM, club=Sampdoria)
# 	CB1: Player(id=10577, name=Pogatetz, overall=68, position=CB, price=500, nationality=Austria, league=Österreichische Fußball-Bundesliga, club=LASK Linz)
# 	CB2: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8880.00
# RATING: 812
# CHEMISTRY: 56
# PRICE: 8000
#
# TURN 7
# PLAYERS:
# 	GK: Player(id=10085, name=Marciano, overall=65, position=GK, price=200, nationality=Israel, league=Scottish Premiership, club=Hibernian)
# 	LB: Player(id=7863, name=Matlaba, overall=74, position=LB, price=600, nationality=South Africa, league=South African FL, club=Orlando Pirates)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8885.00
# RATING: 808
# CHEMISTRY: 61
# PRICE: 8050
#
# TURN 9
# PLAYERS:
# 	GK: Player(id=910, name=Adán, overall=83, position=GK, price=1200, nationality=Spain, league=LaLiga Santander, club=Atlético Madrid)
# 	LB: Player(id=7863, name=Matlaba, overall=74, position=LB, price=600, nationality=South Africa, league=South African FL, club=Orlando Pirates)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=623, name=Odriozola, overall=80, position=RB, price=1200, nationality=Spain, league=LaLiga Santander, club=Real Madrid)
# 	RB: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM3: Player(id=13198, name=Fofana, overall=71, position=CDM, price=400, nationality=France, league=Ligue 1 Conforama, club=En Avant de Guingamp)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8925.00
# RATING: 829
# CHEMISTRY: 53
# PRICE: 8950
#
# TURN 12
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=6396, name=Lemoine, overall=73, position=CDM, price=450, nationality=France, league=Domino’s Ligue 2, club=FC Lorient)
# 	CB1: Player(id=10060, name=Berra, overall=74, position=CB, price=1000, nationality=Scotland, league=Scottish Premiership, club=Heart of Midlothian)
# 	CB2: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CM2: Player(id=4631, name=Waston, overall=74, position=CB, price=400, nationality=Costa Rica, league=Major League Soccer, club=Vancouver Whitecaps FC)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8935.00
# RATING: 825
# CHEMISTRY: 52
# PRICE: 8350
#
# TURN 13
# PLAYERS:
# 	GK: Player(id=13568, name=Lunin, overall=76, position=GK, price=500, nationality=Ukraine, league=LaLiga Santander, club=CD Leganés)
# 	LB: Player(id=7863, name=Matlaba, overall=74, position=LB, price=600, nationality=South Africa, league=South African FL, club=Orlando Pirates)
# 	CB1: Player(id=3146, name=Kolodziejczak, overall=74, position=CB, price=850, nationality=France, league=Ligue 1 Conforama, club=AS Saint-Étienne)
# 	CB2: Player(id=3395, name=Espinosa, overall=77, position=CB, price=900, nationality=Colombia, league=LaLiga Santander, club=Girona FC)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12805, name=Fernández, overall=80, position=CM, price=800, nationality=Argentina, league=CSL, club=Beijing Renhe)
# 	CM2: Player(id=1953, name=Ananidze, overall=75, position=CAM, price=500, nationality=Georgia, league=League of Russia, club=Spartak Moscow)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=7749, name=Templeton, overall=66, position=LM, price=400, nationality=Scotland, league=EFL League One, club=Burton Albion)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8945.00
# RATING: 819
# CHEMISTRY: 51
# PRICE: 7550
#
# TURN 14
# PLAYERS:
# 	GK: Player(id=3187, name=Esser, overall=74, position=GK, price=700, nationality=Germany, league=Bundesliga, club=Hannover 96)
# 	LB: Player(id=2937, name=Pellenard, overall=69, position=LB, price=650, nationality=France, league=Ligue 1 Conforama, club=FC Girondins de Bordeaux)
# 	CB1: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	CB2: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=6396, name=Lemoine, overall=73, position=CDM, price=450, nationality=France, league=Domino’s Ligue 2, club=FC Lorient)
# 	CM2: Player(id=4631, name=Waston, overall=74, position=CB, price=400, nationality=Costa Rica, league=Major League Soccer, club=Vancouver Whitecaps FC)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 8980.00
# RATING: 816
# CHEMISTRY: 57
# PRICE: 7500
#
# TURN 15
# PLAYERS:
# 	GK: Player(id=3187, name=Esser, overall=74, position=GK, price=700, nationality=Germany, league=Bundesliga, club=Hannover 96)
# 	LB: Player(id=2937, name=Pellenard, overall=69, position=LB, price=650, nationality=France, league=Ligue 1 Conforama, club=FC Girondins de Bordeaux)
# 	CB1: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	CB2: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=6396, name=Lemoine, overall=73, position=CDM, price=450, nationality=France, league=Domino’s Ligue 2, club=FC Lorient)
# 	CM2: Player(id=2233, name=Meyer, overall=79, position=CM, price=1000, nationality=Germany, league=Premier League, club=Crystal Palace)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9000.00
# RATING: 821
# CHEMISTRY: 60
# PRICE: 8100
#
# TURN 16
# PLAYERS:
# 	GK: Player(id=3187, name=Esser, overall=74, position=GK, price=700, nationality=Germany, league=Bundesliga, club=Hannover 96)
# 	LB: Player(id=12916, name=Hernanes, overall=78, position=CM, price=1200, nationality=Brazil, league=CSL, club=Hebei China Fortune FC)
# 	CB1: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	CB2: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=6396, name=Lemoine, overall=73, position=CDM, price=450, nationality=France, league=Domino’s Ligue 2, club=FC Lorient)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9025.00
# RATING: 829
# CHEMISTRY: 57
# PRICE: 8350
#
# TURN 18
# PLAYERS:
# 	GK: Player(id=3088, name=Reynet, overall=78, position=GK, price=700, nationality=France, league=Ligue 1 Conforama, club=Toulouse Football Club)
# 	LB: Player(id=2481, name=Schennikov, overall=75, position=LWB, price=1300, nationality=Russia, league=League of Russia, club=CSKA Moscow)
# 	CB1: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	CB2: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=6396, name=Lemoine, overall=73, position=CDM, price=450, nationality=France, league=Domino’s Ligue 2, club=FC Lorient)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9045.00
# RATING: 830
# CHEMISTRY: 59
# PRICE: 8450
#
# TURN 20
# PLAYERS:
# 	GK: Player(id=4520, name=Westwood, overall=75, position=GK, price=500, nationality=Republic of Ireland, league=EFL Championship, club=Sheffield Wednesday)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=12047, name=Fuentes, overall=69, position=CDM, price=200, nationality=Chile, league=Campeonato Scotiabank, club=CD O'Higgins)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9070.00
# RATING: 817
# CHEMISTRY: 60
# PRICE: 7000
#
# TURN 21
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=1374, name=Adriano, overall=78, position=LB, price=1200, nationality=Brazil, league=Süper Lig, club=Beşiktaş JK)
# 	CB1: Player(id=8917, name=Maresic, overall=72, position=CB, price=550, nationality=Austria, league=Österreichische Fußball-Bundesliga, club=SK Sturm Graz)
# 	CB2: Player(id=4032, name=Aguilar, overall=76, position=CB, price=650, nationality=Paraguay, league=LIGA Bancomer MX, club=Cruz Azul)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=13404, name=Faty, overall=70, position=CDM, price=300, nationality=Senegal, league=Süper Lig, club=MKE Ankaragücü)
# 	CM2: Player(id=1003, name=Potuk, overall=76, position=CAM, price=550, nationality=Turkey, league=Süper Lig, club=Fenerbahçe SK)
# 	CM3: Player(id=4469, name=Kalinski, overall=73, position=CM, price=1000, nationality=Argentina, league=SAF, club=Club Atlético Banfield)
# 	LW: Player(id=13297, name=Cristian Tello, overall=80, position=LM, price=900, nationality=Spain, league=LaLiga Santander, club=Real Betis)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9080.00
# RATING: 822
# CHEMISTRY: 62
# PRICE: 7600
#
# TURN 23
# PLAYERS:
# 	GK: Player(id=4520, name=Westwood, overall=75, position=GK, price=500, nationality=Republic of Ireland, league=EFL Championship, club=Sheffield Wednesday)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9155.00
# RATING: 825
# CHEMISTRY: 64
# PRICE: 7350
#
# TURN 25
# PLAYERS:
# 	GK: Player(id=4520, name=Westwood, overall=75, position=GK, price=500, nationality=Republic of Ireland, league=EFL Championship, club=Sheffield Wednesday)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=834, name=Juan Jesus, overall=78, position=CB, price=1300, nationality=Brazil, league=Serie A TIM, club=Roma)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9160.00
# RATING: 831
# CHEMISTRY: 67
# PRICE: 8200
#
# TURN 27
# PLAYERS:
# 	GK: Player(id=8048, name=Van Leer, overall=74, position=GK, price=350, nationality=Holland, league=Eredivisie, club=NAC Breda)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=2462, name=Tapia, overall=74, position=CB, price=1000, nationality=Peru, league=Eredivisie, club=Feyenoord)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9185.00
# RATING: 826
# CHEMISTRY: 70
# PRICE: 7750
#
# TURN 28
# PLAYERS:
# 	GK: Player(id=4520, name=Westwood, overall=75, position=GK, price=500, nationality=Republic of Ireland, league=EFL Championship, club=Sheffield Wednesday)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=3548, name=Chedjou, overall=74, position=CB, price=700, nationality=Cameroon, league=Süper Lig, club=Bursaspor)
# 	CB2: Player(id=13443, name=O'Shea, overall=69, position=CB, price=600, nationality=Republic of Ireland, league=EFL Championship, club=Reading)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9205.00
# RATING: 818
# CHEMISTRY: 76
# PRICE: 7350
#
# TURN 32
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=4032, name=Aguilar, overall=76, position=CB, price=650, nationality=Paraguay, league=LIGA Bancomer MX, club=Cruz Azul)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=1734, name=Javi García, overall=78, position=CDM, price=750, nationality=Spain, league=LaLiga Santander, club=Real Betis)
# 	CM3: Player(id=9725, name=Miranda, overall=72, position=CM, price=1000, nationality=Argentina, league=SAF, club=Defensa y Justicia)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2549, name=Ibai Gómez, overall=79, position=RM, price=1000, nationality=Spain, league=LaLiga Santander, club=D. Alavés)
# FITNESS: 9220.00
# RATING: 828
# CHEMISTRY: 67
# PRICE: 7300
#
# TURN 33
# PLAYERS:
# 	GK: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	LB: Player(id=8210, name=Joãozinho, overall=69, position=LB, price=300, nationality=Portugal, league=Liga NOS, club=Tondela)
# 	CB1: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=1003, name=Potuk, overall=76, position=CAM, price=550, nationality=Turkey, league=Süper Lig, club=Fenerbahçe SK)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9230.00
# RATING: 820
# CHEMISTRY: 64
# PRICE: 6100
#
# TURN 37
# PLAYERS:
# 	GK: Player(id=8048, name=Van Leer, overall=74, position=GK, price=350, nationality=Holland, league=Eredivisie, club=NAC Breda)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=2462, name=Tapia, overall=74, position=CB, price=1000, nationality=Peru, league=Eredivisie, club=Feyenoord)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=12907, name=Mario Suárez, overall=77, position=CM, price=500, nationality=Spain, league=CSL, club=Guizhou Hengfeng FC)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9260.00
# RATING: 837
# CHEMISTRY: 68
# PRICE: 7900
#
# TURN 40
# PLAYERS:
# 	GK: Player(id=8048, name=Van Leer, overall=74, position=GK, price=350, nationality=Holland, league=Eredivisie, club=NAC Breda)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=12907, name=Mario Suárez, overall=77, position=CM, price=500, nationality=Spain, league=CSL, club=Guizhou Hengfeng FC)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9275.00
# RATING: 834
# CHEMISTRY: 65
# PRICE: 7150
#
# TURN 41
# PLAYERS:
# 	GK: Player(id=8048, name=Van Leer, overall=74, position=GK, price=350, nationality=Holland, league=Eredivisie, club=NAC Breda)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=13487, name=Servando, overall=69, position=CB, price=400, nationality=Spain, league=LaLiga 1 I 2 I 3, club=Cádiz CF)
# 	CB2: Player(id=2462, name=Tapia, overall=74, position=CB, price=1000, nationality=Peru, league=Eredivisie, club=Feyenoord)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=12907, name=Mario Suárez, overall=77, position=CM, price=500, nationality=Spain, league=CSL, club=Guizhou Hengfeng FC)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9305.00
# RATING: 828
# CHEMISTRY: 77
# PRICE: 7450
#
# TURN 54
# PLAYERS:
# 	GK: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	LB: Player(id=14326, name=Mazáň, overall=68, position=LB, price=600, nationality=Slovakia, league=LaLiga Santander, club=RC Celta)
# 	CB1: Player(id=3889, name=Kucher, overall=74, position=CB, price=700, nationality=Ukraine, league=Süper Lig, club=Kayserispor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=12907, name=Mario Suárez, overall=77, position=CM, price=500, nationality=Spain, league=CSL, club=Guizhou Hengfeng FC)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9320.00
# RATING: 822
# CHEMISTRY: 76
# PRICE: 6600
#
# TURN 57
# PLAYERS:
# 	GK: Player(id=6307, name=Farnolle, overall=66, position=GK, price=300, nationality=Benin, league=Süper Lig, club=Evkur Yeni Malatyaspor)
# 	LB: Player(id=10910, name=Kallaste, overall=67, position=LB, price=300, nationality=Estonia, league=Ekstraklasa, club=Korona Kielce)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM2: Player(id=12907, name=Mario Suárez, overall=77, position=CM, price=500, nationality=Spain, league=CSL, club=Guizhou Hengfeng FC)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=15935, name=Bruno Tabata, overall=70, position=RW, price=350, nationality=Brazil, league=Liga NOS, club=Portimonense SC)
# FITNESS: 9345.00
# RATING: 817
# CHEMISTRY: 75
# PRICE: 5750
#
# TURN 62
# PLAYERS:
# 	GK: Player(id=7559, name=Werner, overall=72, position=GK, price=500, nationality=Argentina, league=LaLiga Santander, club=SD Huesca)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=2213, name=Paulo Oliveira, overall=78, position=CB, price=800, nationality=Portugal, league=LaLiga Santander, club=SD Eibar)
# 	CB2: Player(id=4097, name=Domingo, overall=76, position=CDM, price=500, nationality=Argentina, league=SAF, club=Independiente)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1530, name=Benassi, overall=77, position=CM, price=600, nationality=Italy, league=Serie A TIM, club=Fiorentina)
# 	CM2: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2846, name=Pussetto, overall=74, position=RW, price=900, nationality=Argentina, league=Serie A TIM, club=Udinese)
# FITNESS: 9380.00
# RATING: 839
# CHEMISTRY: 77
# PRICE: 7800
#
# TURN 65
# PLAYERS:
# 	GK: Player(id=6307, name=Farnolle, overall=66, position=GK, price=300, nationality=Benin, league=Süper Lig, club=Evkur Yeni Malatyaspor)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3586, name=Rober Ibáñez, overall=72, position=RM, price=700, nationality=Spain, league=LaLiga Santander, club=Getafe CF)
# FITNESS: 9390.00
# RATING: 827
# CHEMISTRY: 83
# PRICE: 6800
#
# TURN 66
# PLAYERS:
# 	GK: Player(id=6307, name=Farnolle, overall=66, position=GK, price=300, nationality=Benin, league=Süper Lig, club=Evkur Yeni Malatyaspor)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=837, name=Ünder, overall=77, position=RW, price=750, nationality=Turkey, league=Serie A TIM, club=Roma)
# FITNESS: 9405.00
# RATING: 832
# CHEMISTRY: 77
# PRICE: 6850
#
# TURN 68
# PLAYERS:
# 	GK: Player(id=1386, name=Zengin, overall=72, position=GK, price=450, nationality=Turkey, league=Süper Lig, club=Beşiktaş JK)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=11618, name=Cadden, overall=69, position=RM, price=200, nationality=Scotland, league=Scottish Premiership, club=Motherwell)
# FITNESS: 9415.00
# RATING: 830
# CHEMISTRY: 76
# PRICE: 6450
#
# TURN 73
# PLAYERS:
# 	GK: Player(id=6307, name=Farnolle, overall=66, position=GK, price=300, nationality=Benin, league=Süper Lig, club=Evkur Yeni Malatyaspor)
# 	LB: Player(id=1783, name=Lato, overall=75, position=LB, price=950, nationality=Spain, league=LaLiga Santander, club=Valencia CF)
# 	CB1: Player(id=4596, name=Welinton, overall=73, position=CB, price=300, nationality=Brazil, league=Süper Lig, club=Alanyaspor)
# 	CB2: Player(id=5630, name=Bjärsmyr, overall=71, position=CB, price=250, nationality=Sweden, league=Süper Lig, club=Sivasspor)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM2: Player(id=1660, name=Radoja, overall=77, position=CM, price=550, nationality=Serbia, league=LaLiga Santander, club=RC Celta)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=3472, name=Hélder Costa, overall=75, position=RW, price=550, nationality=Portugal, league=Premier League, club=Wolverhampton Wanderers)
# FITNESS: 9435.00
# RATING: 830
# CHEMISTRY: 82
# PRICE: 6650
#
# TURN 106
# PLAYERS:
# 	GK: Player(id=4601, name=Yilmaz, overall=69, position=GK, price=200, nationality=Turkey, league=Süper Lig, club=Alanyaspor)
# 	LB: Player(id=2717, name=Ward, overall=76, position=LB, price=1000, nationality=Republic of Ireland, league=Premier League, club=Burnley)
# ...
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=3392, name=Borja García, overall=79, position=LM, price=1000, nationality=Spain, league=LaLiga Santander, club=Girona FC)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9540.00
# RATING: 862
# CHEMISTRY: 84
# PRICE: 8800
#
# TURN 242
# PLAYERS:
# 	GK: Player(id=3953, name=Fabricio, overall=80, position=GK, price=900, nationality=Spain, league=Premier League, club=Fulham)
# 	LB: Player(id=753, name=Maksimovic, overall=78, position=CB, price=850, nationality=Serbia, league=Serie A TIM, club=Napoli)
# 	CB1: Player(id=485, name=Lovren, overall=81, position=CB, price=1000, nationality=Croatia, league=Premier League, club=Liverpool)
# 	CB2: Player(id=1102, name=Víctor Ruíz, overall=82, position=CB, price=1400, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=3500, name=Valdifiori, overall=75, position=CDM, price=600, nationality=Italy, league=Serie A TIM, club=SPAL)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9570.00
# RATING: 869
# CHEMISTRY: 80
# PRICE: 9200
#
# TURN 290
# PLAYERS:
# 	GK: Player(id=13568, name=Lunin, overall=76, position=GK, price=500, nationality=Ukraine, league=LaLiga Santander, club=CD Leganés)
# 	LB: Player(id=12579, name=Paletta, overall=77, position=CB, price=650, nationality=Italy, league=CSL, club=Jiangsu Suning FC)
# 	CB1: Player(id=1869, name=Timor, overall=76, position=CDM, price=600, nationality=Spain, league=LaLiga 1 I 2 I 3, club=UD Las Palmas)
# 	CB2: Player(id=1102, name=Víctor Ruíz, overall=82, position=CB, price=1400, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1459, name=Mikel San José, overall=77, position=CM, price=600, nationality=Spain, league=LaLiga Santander, club=Athletic Club)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9590.00
# RATING: 861
# CHEMISTRY: 82
# PRICE: 8200
#
# TURN 366
# PLAYERS:
# 	GK: Player(id=1080, name=Vaclík, overall=78, position=GK, price=500, nationality=Czech Republic, league=LaLiga Santander, club=Sevilla FC)
# 	LB: Player(id=1869, name=Timor, overall=76, position=CDM, price=600, nationality=Spain, league=LaLiga 1 I 2 I 3, club=UD Las Palmas)
# 	CB1: Player(id=8181, name=Maurício, overall=74, position=CB, price=450, nationality=Brazil, league=Meiji Yasuda J1 League, club=Urawa Red Diamonds)
# 	CB2: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=7533, name=Melero, overall=75, position=CM, price=600, nationality=Spain, league=LaLiga Santander, club=SD Huesca)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9600.00
# RATING: 855
# CHEMISTRY: 82
# PRICE: 7500
#
# TURN 369
# PLAYERS:
# 	GK: Player(id=200, name=Bürki, overall=81, position=GK, price=750, nationality=Switzerland, league=Bundesliga, club=Borussia Dortmund)
# 	LB: Player(id=1869, name=Timor, overall=76, position=CDM, price=600, nationality=Spain, league=LaLiga 1 I 2 I 3, club=UD Las Palmas)
# 	CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CB2: Player(id=8181, name=Maurício, overall=74, position=CB, price=450, nationality=Brazil, league=Meiji Yasuda J1 League, club=Urawa Red Diamonds)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=7533, name=Melero, overall=75, position=CM, price=600, nationality=Spain, league=LaLiga Santander, club=SD Huesca)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9605.00
# RATING: 858
# CHEMISTRY: 80
# PRICE: 7750
#
# TURN 477
# PLAYERS:
# 	GK: Player(id=2550, name=Pacheco, overall=79, position=GK, price=600, nationality=Spain, league=LaLiga Santander, club=D. Alavés)
# 	LB: Player(id=5482, name=Bjelica, overall=71, position=LWB, price=350, nationality=Serbia, league=Belgium Pro League, club=KV Oostende)
# 	CB1: Player(id=13442, name=Pejčinović, overall=77, position=CB, price=450, nationality=Serbia, league=CSL, club=Changchun Yatai FC)
# 	CB2: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=3231, name=Grenier, overall=78, position=CAM, price=600, nationality=France, league=Ligue 1 Conforama, club=Stade Rennais FC)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9625.00
# RATING: 857
# CHEMISTRY: 79
# PRICE: 7350
#
# TURN 506
# PLAYERS:
# 	GK: Player(id=3265, name=Oier, overall=75, position=GK, price=500, nationality=Spain, league=LaLiga Santander, club=Levante UD)
# 	LB: Player(id=13442, name=Pejčinović, overall=77, position=CB, price=450, nationality=Serbia, league=CSL, club=Changchun Yatai FC)
# 	CB1: Player(id=3205, name=Hilton, overall=78, position=CB, price=850, nationality=Brazil, league=Ligue 1 Conforama, club=Montpellier Hérault SC)
# 	CB2: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1163, name=Fejsa, overall=82, position=CDM, price=950, nationality=Serbia, league=Liga NOS, club=SL Benfica)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9630.00
# RATING: 864
# CHEMISTRY: 80
# PRICE: 8100
#
# TURN 538
# PLAYERS:
# 	GK: Player(id=3265, name=Oier, overall=75, position=GK, price=500, nationality=Spain, league=LaLiga Santander, club=Levante UD)
# 	LB: Player(id=13442, name=Pejčinović, overall=77, position=CB, price=450, nationality=Serbia, league=CSL, club=Changchun Yatai FC)
# 	CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CB2: Player(id=4631, name=Waston, overall=74, position=CB, price=400, nationality=Costa Rica, league=Major League Soccer, club=Vancouver Whitecaps FC)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1163, name=Fejsa, overall=82, position=CDM, price=950, nationality=Serbia, league=Liga NOS, club=SL Benfica)
# 	CM2: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9635.00
# RATING: 860
# CHEMISTRY: 80
# PRICE: 7650
#
# TURN 565
# PLAYERS:
# 	GK: Player(id=371, name=Cillessen, overall=81, position=GK, price=800, nationality=Holland, league=LaLiga Santander, club=FC Barcelona)
# 	LB: Player(id=1732, name=Mandi, overall=79, position=CB, price=850, nationality=Algeria, league=LaLiga Santander, club=Real Betis)
# 	CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CB2: Player(id=2552, name=Manu García, overall=78, position=CDM, price=600, nationality=Spain, league=LaLiga Santander, club=D. Alavés)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM2: Player(id=1111, name=Javi Fuego, overall=78, position=CDM, price=600, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=378, name=Munir, overall=77, position=ST, price=600, nationality=Spain, league=LaLiga Santander, club=FC Barcelona)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9660.00
# RATING: 868
# CHEMISTRY: 93
# PRICE: 8200
#
# TURN 587
# PLAYERS:
# 	GK: Player(id=371, name=Cillessen, overall=81, position=GK, price=800, nationality=Holland, league=LaLiga Santander, club=FC Barcelona)
# 	LB: Player(id=1732, name=Mandi, overall=79, position=CB, price=850, nationality=Algeria, league=LaLiga Santander, club=Real Betis)
# 	CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CB2: Player(id=2552, name=Manu García, overall=78, position=CDM, price=600, nationality=Spain, league=LaLiga Santander, club=D. Alavés)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM2: Player(id=1654, name=Lobotka, overall=78, position=CM, price=550, nationality=Slovakia, league=LaLiga Santander, club=RC Celta)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=13412, name=Loren, overall=78, position=ST, price=700, nationality=Spain, league=LaLiga Santander, club=Real Betis)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9665.00
# RATING: 869
# CHEMISTRY: 85
# PRICE: 8250
#
# FINAL CHAMPION
# PLAYERS:
# 	GK: Player(id=371, name=Cillessen, overall=81, position=GK, price=800, nationality=Holland, league=LaLiga Santander, club=FC Barcelona)
# 	LB: Player(id=1732, name=Mandi, overall=79, position=CB, price=850, nationality=Algeria, league=LaLiga Santander, club=Real Betis)
# 	CB1: Player(id=1108, name=Álvaro, overall=79, position=CB, price=900, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CB2: Player(id=2552, name=Manu García, overall=78, position=CDM, price=600, nationality=Spain, league=LaLiga Santander, club=D. Alavés)
# 	RB: Player(id=4096, name=Bustos, overall=76, position=RB, price=700, nationality=Argentina, league=SAF, club=Independiente)
# 	CM1: Player(id=1099, name=Manu Trigueros, overall=83, position=CM, price=750, nationality=Spain, league=LaLiga Santander, club=Villarreal CF)
# 	CM2: Player(id=1654, name=Lobotka, overall=78, position=CM, price=550, nationality=Slovakia, league=LaLiga Santander, club=RC Celta)
# 	CM3: Player(id=2754, name=Gago, overall=78, position=CM, price=700, nationality=Argentina, league=SAF, club=Buenos Aires)
# 	LW: Player(id=1392, name=Piatti, overall=79, position=LM, price=800, nationality=Argentina, league=LaLiga Santander, club=RCD Espanyol)
# 	ST: Player(id=13412, name=Loren, overall=78, position=ST, price=700, nationality=Spain, league=LaLiga Santander, club=Real Betis)
# 	RW: Player(id=2750, name=Pavón, overall=80, position=RW, price=900, nationality=Argentina, league=SAF, club=Buenos Aires)
# FITNESS: 9665.00
# RATING: 869
# CHEMISTRY: 85
# PRICE: 8250

# %%
with open("../input/champion_log.p", "wb") as f:
    pickle.dump(champion_log, f)

# %%
x = np.arange(0, N_GENERATIONS)
fig, axs = plt.subplots(4, 1, figsize=(16, 12))

for ax, data, title in zip(axs, [fitness_log, rating_log, chemistry_log, price_log], ["Fitness", "Rating", "Chemistry", "Price"]):
    ax.plot(x, data, linewidth=3, color=cmap(1.))
    ax.set_title(label=title)
    ax.set_xlabel("Generation")    
    
fig.tight_layout()

plt.savefig("../images/fitness_curve.png", dpi=120)
